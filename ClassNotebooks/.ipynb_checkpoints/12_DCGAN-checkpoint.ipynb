# %% [markdown]
# # Notebook 12: Using a GAN to generate new Pokemon images

# %%
# For tips on running notebooks in Google Colab, see
# https://pytorch.org/tutorials/beginner/colab
# %matplotlib inline

# %% [markdown]
# DCGAN Tutorial
# ==============
#
# **Author**: [Nathan Inkawhich](https://github.com/inkawhich)

# %% [markdown]
# Introduction
# ============
#
# This tutorial will give an introduction to DCGANs through an example. We
# will train a generative adversarial network (GAN) to generate new
# celebrities after showing it pictures of many real celebrities. Most of
# the code here is from the DCGAN implementation in
# [pytorch/examples](https://github.com/pytorch/examples), and this
# document will give a thorough explanation of the implementation and shed
# light on how and why this model works. But don't worry, no prior
# knowledge of GANs is required, but it may require a first-timer to spend
# some time reasoning about what is actually happening under the hood.
# Also, for the sake of time it will help to have a GPU, or two. Lets
# start from the beginning.
#
# Generative Adversarial Networks
# ===============================
#
# What is a GAN?
# --------------
#
# GANs are a framework for teaching a deep learning model to capture the
# training data distribution so we can generate new data from that same
# distribution. GANs were invented by Ian Goodfellow in 2014 and first
# described in the paper [Generative Adversarial
# Nets](https://papers.nips.cc/paper/5423-generative-adversarial-nets.pdf).
# They are made of two distinct models, a *generator* and a
# *discriminator*. The job of the generator is to spawn 'fake' images that
# look like the training images. The job of the discriminator is to look
# at an image and output whether or not it is a real training image or a
# fake image from the generator. During training, the generator is
# constantly trying to outsmart the discriminator by generating better and
# better fakes, while the discriminator is working to become a better
# detective and correctly classify the real and fake images. The
# equilibrium of this game is when the generator is generating perfect
# fakes that look as if they came directly from the training data, and the
# discriminator is left to always guess at 50% confidence that the
# generator output is real or fake.
#
# Now, lets define some notation to be used throughout tutorial starting
# with the discriminator. Let $x$ be data representing an image. $D(x)$ is
# the discriminator network which outputs the (scalar) probability that
# $x$ came from training data rather than the generator. Here, since we
# are dealing with images, the input to $D(x)$ is an image of CHW size
# 3x64x64. Intuitively, $D(x)$ should be HIGH when $x$ comes from training
# data and LOW when $x$ comes from the generator. $D(x)$ can also be
# thought of as a traditional binary classifier.
#
# For the generator's notation, let $z$ be a latent space vector sampled
# from a standard normal distribution. $G(z)$ represents the generator
# function which maps the latent vector $z$ to data-space. The goal of $G$
# is to estimate the distribution that the training data comes from
# ($p_{data}$) so it can generate fake samples from that estimated
# distribution ($p_g$).
#
# So, $D(G(z))$ is the probability (scalar) that the output of the
# generator $G$ is a real image. As described in [Goodfellow's
# paper](https://papers.nips.cc/paper/5423-generative-adversarial-nets.pdf),
# $D$ and $G$ play a minimax game in which $D$ tries to maximize the
# probability it correctly classifies reals and fakes ($logD(x)$), and $G$
# tries to minimize the probability that $D$ will predict its outputs are
# fake ($log(1-D(G(z)))$). From the paper, the GAN loss function is
#
# $$\underset{G}{\text{min}} \underset{D}{\text{max}}V(D,G) = \mathbb{E}_{x\sim p_{data}(x)}\big[logD(x)\big] + \mathbb{E}_{z\sim p_{z}(z)}\big[log(1-D(G(z)))\big]$$
#
# In theory, the solution to this minimax game is where $p_g = p_{data}$,
# and the discriminator guesses randomly if the inputs are real or fake.
# However, the convergence theory of GANs is still being actively
# researched and in reality models do not always train to this point.
#
# What is a DCGAN?
# ----------------
#
# A DCGAN is a direct extension of the GAN described above, except that it
# explicitly uses convolutional and convolutional-transpose layers in the
# discriminator and generator, respectively. It was first described by
# Radford et. al. in the paper [Unsupervised Representation Learning With
# Deep Convolutional Generative Adversarial
# Networks](https://arxiv.org/pdf/1511.06434.pdf). The discriminator is
# made up of strided
# [convolution](https://pytorch.org/docs/stable/nn.html#torch.nn.Conv2d)
# layers, [batch
# norm](https://pytorch.org/docs/stable/nn.html#torch.nn.BatchNorm2d)
# layers, and
# [LeakyReLU](https://pytorch.org/docs/stable/nn.html#torch.nn.LeakyReLU)
# activations. The input is a 3x64x64 input image and the output is a
# scalar probability that the input is from the real data distribution.
# The generator is comprised of
# [convolutional-transpose](https://pytorch.org/docs/stable/nn.html#torch.nn.ConvTranspose2d)
# layers, batch norm layers, and
# [ReLU](https://pytorch.org/docs/stable/nn.html#relu) activations. The
# input is a latent vector, $z$, that is drawn from a standard normal
# distribution and the output is a 3x64x64 RGB image. The strided
# conv-transpose layers allow the latent vector to be transformed into a
# volume with the same shape as an image. In the paper, the authors also
# give some tips about how to setup the optimizers, how to calculate the
# loss functions, and how to initialize the model weights, all of which
# will be explained in the coming sections.

# %%
#%matplotlib inline
import argparse
import os
import random
import torch
import torch.nn as nn
import torch.nn.parallel
import torch.optim as optim
import torch.utils.data
import torchvision.datasets as dset
import torchvision.transforms as transforms
import torchvision.utils as vutils
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML

# Set random seed for reproducibility
manualSeed = 999
#manualSeed = random.randint(1, 10000) # use if you want new results
print("Random Seed: ", manualSeed)
random.seed(manualSeed)
torch.manual_seed(manualSeed)
torch.use_deterministic_algorithms(True) # Needed for reproducible results
# Out:
# Random Seed:  999

# %% [markdown]
# Inputs
# ======
#
# Let's define some inputs for the run:
#
# -   `dataroot` - the path to the root of the dataset folder. We will
#     talk more about the dataset in the next section.
# -   `workers` - the number of worker threads for loading the data with
#     the `DataLoader`.
# -   `batch_size` - the batch size used in training. The DCGAN paper uses
#     a batch size of 128.
# -   `image_size` - the spatial size of the images used for training.
#     This implementation defaults to 64x64. If another size is desired,
#     the structures of D and G must be changed. See
#     [here](https://github.com/pytorch/examples/issues/70) for more
#     details.
# -   `nc` - number of color channels in the input images. For color
#     images this is 3.
# -   `nz` - length of latent vector.
# -   `ngf` - relates to the depth of feature maps carried through the
#     generator.
# -   `ndf` - sets the depth of feature maps propagated through the
#     discriminator.
# -   `num_epochs` - number of training epochs to run. Training for longer
#     will probably lead to better results but will also take much longer.
# -   `lr` - learning rate for training. As described in the DCGAN paper,
#     this number should be 0.0002.
# -   `beta1` - beta1 hyperparameter for Adam optimizers. As described in
#     paper, this number should be 0.5.
# -   `ngpu` - number of GPUs available. If this is 0, code will run in
#     CPU mode. If this number is greater than 0 it will run on that
#     number of GPUs.

# %%
# Root directory for dataset
dataroot = "images"

# Number of workers for dataloader
workers = 2

# Batch size during training
batch_size = 16

# Spatial size of training images. All images will be resized to this
#   size using a transformer.
image_size = 64

# Number of channels in the training images. For color images this is 3
nc = 3

# Size of z latent vector (i.e. size of generator input)
nz = 100

# Size of feature maps in generator
ngf = 64

# Size of feature maps in discriminator
ndf = 64

# Number of training epochs
num_epochs = 20

# Learning rate for optimizers
lr = 0.0002

# Beta1 hyperparameter for Adam optimizers
beta1 = 0.5

# Number of GPUs available. Use 0 for CPU mode.
ngpu = 1

# %% [markdown]
# Data
# ====
#
# In this tutorial we will use the [Complete Pokemon Image Dataset](https://www.kaggle.com/datasets/hlrhegemony/pokemon-image-dataset/data) which can be
# downloaded at the linked site, or [here](https://www.physi.uni-heidelberg.de/~dittmeier/pytorch/notebooks/pokemon_images.zip).
# The dataset will download as a file named `pokemon_images.zip`. Once
# downloaded, extract the zip file. Then, set the `dataroot` input for this notebook to
# the `images` directory you just created from unzipping. The resulting directory
# structure should be:
#
# ``` {.sourceCode .sh}
# /path/to/images
#     -> Abomasnow
#         -> 0.jpg
#         -> 1.jpg
#         -> 2.jpg
#         -> 3.jpg
#     -> Abra
#            ...
# ```
#
# This is an important step because we will be using the `ImageFolder`
# dataset class, which requires there to be subdirectories in the dataset
# root folder. Now, we can create the dataset, create the dataloader, set
# the device to run on, and finally visualize some of the training data.

# %%
# !wget --no-check-certificate https://www.physi.uni-heidelberg.de/~dittmeier/pytorch/notebooks/pokemon_images.zip
# Out:
# 7[Files: 0  Bytes: 0  [0 B/s] Re]87WARNING: The certificate is NOT trusted. The certificate issuer is unknown.
# 87[https://www.physi.uni-heidelbe]87Saving 'pokemon_images.zip.1'
# 87pokemon_images.zip.1 100% [=============================>]   57.85M    --.-KB/s87HTTP response 200 OK [https://www.physi.uni-heidelberg.de/~dittmeier/pytorch/notebooks/pokemon_images.zip]
# 87pokemon_images.zip.1 100% [=============================>]   57.85M    --.-KB/s87[Files: 1  Bytes: 57.85M [107.5]8

# %%
# !mkdir images

# %%
# !unzip pokemon_images.zip -d images
# Out:
# Archive:  pokemon_images.zip
#   inflating: images/images/Abomasnow/0.jpg
#   inflating: images/images/Abomasnow/1.jpg
#   inflating: images/images/Abomasnow/2.jpg
#   inflating: images/images/Abomasnow/3.jpg
#   inflating: images/images/Abra/0.jpg
#   inflating: images/images/Abra/1.jpg
#   inflating: images/images/Abra/2.jpg
#   inflating: images/images/Abra/3.jpg
#   inflating: images/images/Absol/0.jpg
#   inflating: images/images/Absol/1.jpg
#   inflating: images/images/Absol/2.jpg
#   inflating: images/images/Absol/3.jpg
#   inflating: images/images/Accelgor/0.jpg
#   inflating: images/images/Accelgor/1.jpg
#   inflating: images/images/Aegislash/0.jpg
#   inflating: images/images/Aegislash/1.jpg
#   inflating: images/images/Aegislash/2.jpg
#   inflating: images/images/Aegislash/3.jpg
#   inflating: images/images/Aerodactyl/0.jpg
#   inflating: images/images/Aerodactyl/1.jpg
#   inflating: images/images/Aerodactyl/2.jpg
#   inflating: images/images/Aerodactyl/3.jpg
#   inflating: images/images/Aerodactyl/4.jpg
#   inflating: images/images/Aerodactyl/5.jpg
#   inflating: images/images/Aggron/0.jpg
#   inflating: images/images/Aggron/1.jpg
#   inflating: images/images/Aggron/2.jpg
#   inflating: images/images/Aggron/3.jpg
#   inflating: images/images/Aipom/0.jpg
#   inflating: images/images/Aipom/1.jpg
#   inflating: images/images/Aipom/2.jpg
#   inflating: images/images/Alakazam/0.jpg
#   inflating: images/images/Alakazam/1.jpg
#   inflating: images/images/Alakazam/2.jpg
#   inflating: images/images/Alakazam/3.jpg
#   inflating: images/images/Alakazam/4.jpg
#   inflating: images/images/Alakazam/5.jpg
#   inflating: images/images/Alcremie/0.jpg
#   inflating: images/images/Alcremie/1.jpg
#   inflating: images/images/Alomomola/0.jpg
#   inflating: images/images/Alomomola/1.jpg
#   inflating: images/images/Altaria/0.jpg
#   inflating: images/images/Altaria/1.jpg
#   inflating: images/images/Altaria/2.jpg
#   inflating: images/images/Altaria/3.jpg
#   inflating: images/images/Amaura/0.jpg
#   inflating: images/images/Amaura/1.jpg
#   inflating: images/images/Ambipom/0.jpg
#   inflating: images/images/Ambipom/1.jpg
#   inflating: images/images/Amoonguss/0.jpg
#   inflating: images/images/Amoonguss/1.jpg
#   inflating: images/images/Ampharos/0.jpg
#   inflating: images/images/Ampharos/1.jpg
#   inflating: images/images/Ampharos/2.jpg
#   inflating: images/images/Ampharos/3.jpg
#   inflating: images/images/Ampharos/4.jpg
#   inflating: images/images/Anorith/0.jpg
#   inflating: images/images/Anorith/1.jpg
#   inflating: images/images/Appletun/0.jpg
#   inflating: images/images/Appletun/1.jpg
#   inflating: images/images/Applin/0.jpg
#   inflating: images/images/Araquanid/0.jpg
#   inflating: images/images/Araquanid/1.jpg
#   inflating: images/images/Arbok/0.jpg
#   inflating: images/images/Arbok/1.jpg
#   inflating: images/images/Arbok/2.jpg
#   inflating: images/images/Arbok/3.jpg
#   inflating: images/images/Arcanine/0.jpg
#   inflating: images/images/Arcanine/1.jpg
#   inflating: images/images/Arcanine/2.jpg
#   inflating: images/images/Arcanine/3.jpg
#   inflating: images/images/Arceus/0.jpg
#   inflating: images/images/Arceus/1.jpg
#   inflating: images/images/Arceus/2.jpg
#   inflating: images/images/Arceus/3.jpg
#   inflating: images/images/Arceus/4.jpg
#   inflating: images/images/Archen/0.jpg
#   inflating: images/images/Archen/1.jpg
#   inflating: images/images/Archeops/0.jpg
#   inflating: images/images/Archeops/1.jpg
#   inflating: images/images/Arctovish/0.jpg
#   inflating: images/images/Arctozolt/0.jpg
#   inflating: images/images/Ariados/0.jpg
#   inflating: images/images/Ariados/1.jpg
#   inflating: images/images/Ariados/2.jpg
#   inflating: images/images/Armaldo/0.jpg
#   inflating: images/images/Armaldo/1.jpg
#   inflating: images/images/Aromatisse/0.jpg
#   inflating: images/images/Aromatisse/1.jpg
#   inflating: images/images/Aron/0.jpg
#   inflating: images/images/Aron/1.jpg
#   inflating: images/images/Arrokuda/0.jpg
#   inflating: images/images/Articuno/0.jpg
#   inflating: images/images/Articuno/1.jpg
#   inflating: images/images/Articuno/2.jpg
#   inflating: images/images/Articuno/3.jpg
#   inflating: images/images/Articuno/4.jpg
#   inflating: images/images/Articuno/5.jpg
#   inflating: images/images/Audino/0.jpg
#   inflating: images/images/Audino/1.jpg
#   inflating: images/images/Audino/2.jpg
#   inflating: images/images/Audino/3.jpg
#   inflating: images/images/Aurorus/0.jpg
#   inflating: images/images/Aurorus/1.jpg
#   inflating: images/images/Avalugg/0.jpg
#   inflating: images/images/Avalugg/1.jpg
#   inflating: images/images/Axew/0.jpg
#   inflating: images/images/Axew/1.jpg
#   inflating: images/images/Azelf/0.jpg
#   inflating: images/images/Azelf/1.jpg
#   inflating: images/images/Azumarill/0.jpg
#   inflating: images/images/Azumarill/1.jpg
#   inflating: images/images/Azumarill/2.jpg
#   inflating: images/images/Azurill/0.jpg
#   inflating: images/images/Azurill/1.jpg
#   inflating: images/images/Bagon/0.jpg
#   inflating: images/images/Bagon/1.jpg
#   inflating: images/images/Baltoy/0.jpg
#   inflating: images/images/Baltoy/1.jpg
#   inflating: images/images/Banette/0.jpg
#   inflating: images/images/Banette/1.jpg
#   inflating: images/images/Banette/2.jpg
#   inflating: images/images/Banette/3.jpg
#   inflating: images/images/Barbaracle/0.jpg
#   inflating: images/images/Barbaracle/1.jpg
#   inflating: images/images/Barboach/0.jpg
#   inflating: images/images/Barboach/1.jpg
#   inflating: images/images/Barraskewda/0.jpg
#   inflating: images/images/Basculin/0.jpg
#   inflating: images/images/Basculin/1.jpg
#   inflating: images/images/Basculin/2.jpg
#   inflating: images/images/Basculin/3.jpg
#   inflating: images/images/Bastiodon/0.jpg
#   inflating: images/images/Bastiodon/1.jpg
#   inflating: images/images/Bayleef/0.jpg
#   inflating: images/images/Bayleef/1.jpg
#   inflating: images/images/Bayleef/2.jpg
#   inflating: images/images/Beartic/0.jpg
#   inflating: images/images/Beartic/1.jpg
#   inflating: images/images/Beautifly/0.jpg
#   inflating: images/images/Beautifly/1.jpg
#   inflating: images/images/Beedrill/0.jpg
#   inflating: images/images/Beedrill/1.jpg
#   inflating: images/images/Beedrill/2.jpg
#   inflating: images/images/Beedrill/3.jpg
#   inflating: images/images/Beedrill/4.jpg
#   inflating: images/images/Beedrill/5.jpg
#   inflating: images/images/Beheeyem/0.jpg
#   inflating: images/images/Beheeyem/1.jpg
#   inflating: images/images/Beldum/0.jpg
#   inflating: images/images/Beldum/1.jpg
#   inflating: images/images/Beldum/2.jpg
#   inflating: images/images/Bellossom/0.jpg
#   inflating: images/images/Bellossom/1.jpg
#   inflating: images/images/Bellossom/2.jpg
#   inflating: images/images/Bellsprout/0.jpg
#   inflating: images/images/Bellsprout/1.jpg
#   inflating: images/images/Bellsprout/2.jpg
#   inflating: images/images/Bellsprout/3.jpg
#   inflating: images/images/Bergmite/0.jpg
#   inflating: images/images/Bergmite/1.jpg
#   inflating: images/images/Bewear/0.jpg
#   inflating: images/images/Bewear/1.jpg
#   inflating: images/images/Bewear/2.jpg
#   inflating: images/images/Bibarel/0.jpg
#   inflating: images/images/Bibarel/1.jpg
#   inflating: images/images/Bidoof/0.jpg
#   inflating: images/images/Bidoof/1.jpg
#   inflating: images/images/Binacle/0.jpg
#   inflating: images/images/Binacle/1.jpg
#   inflating: images/images/Bisharp/0.jpg
#   inflating: images/images/Bisharp/1.jpg
#   inflating: images/images/Blacephalon/0.jpg
#   inflating: images/images/Blacephalon/1.jpg
#   inflating: images/images/Blastoise/0.jpg
#   inflating: images/images/Blastoise/1.jpg
#   inflating: images/images/Blastoise/2.jpg
#   inflating: images/images/Blastoise/3.jpg
#   inflating: images/images/Blastoise/4.jpg
#   inflating: images/images/Blastoise/5.jpg
#   inflating: images/images/Blaziken/0.jpg
#   inflating: images/images/Blaziken/1.jpg
#   inflating: images/images/Blaziken/2.jpg
#   inflating: images/images/Blaziken/3.jpg
#   inflating: images/images/Blipbug/0.jpg
#   inflating: images/images/Blissey/0.jpg
#   inflating: images/images/Blissey/1.jpg
#   inflating: images/images/Blissey/2.jpg
#   inflating: images/images/Blitzle/0.jpg
#   inflating: images/images/Blitzle/1.jpg
#   inflating: images/images/Boldore/0.jpg
#   inflating: images/images/Boldore/1.jpg
#   inflating: images/images/Boltund/0.jpg
#   inflating: images/images/Bonsly/0.jpg
#   inflating: images/images/Bonsly/1.jpg
#   inflating: images/images/Bouffalant/0.jpg
#   inflating: images/images/Bouffalant/1.jpg
#   inflating: images/images/Bounsweet/0.jpg
#   inflating: images/images/Bounsweet/1.jpg
#   inflating: images/images/Braixen/0.jpg
#   inflating: images/images/Braixen/1.jpg
#   inflating: images/images/Braviary/0.jpg
#   inflating: images/images/Braviary/1.jpg
#   inflating: images/images/Breloom/0.jpg
#   inflating: images/images/Breloom/1.jpg
#   inflating: images/images/Brionne/0.jpg
#   inflating: images/images/Brionne/1.jpg
#   inflating: images/images/Brionne/2.jpg
#   inflating: images/images/Bronzong/0.jpg
#   inflating: images/images/Bronzong/1.jpg
#   inflating: images/images/Bronzor/0.jpg
#   inflating: images/images/Bronzor/1.jpg
#   inflating: images/images/Bruxish/0.jpg
#   inflating: images/images/Bruxish/1.jpg
#   inflating: images/images/Budew/0.jpg
#   inflating: images/images/Budew/1.jpg
#   inflating: images/images/Buizel/0.jpg
#   inflating: images/images/Buizel/1.jpg
#   inflating: images/images/Bulbasaur/0.jpg
#   inflating: images/images/Bulbasaur/1.jpg
#   inflating: images/images/Bulbasaur/2.jpg
#   inflating: images/images/Buneary/0.jpg
#   inflating: images/images/Buneary/1.jpg
#   inflating: images/images/Bunnelby/0.jpg
#   inflating: images/images/Bunnelby/1.jpg
#   inflating: images/images/Burmy/0.jpg
#   inflating: images/images/Burmy/1.jpg
#   inflating: images/images/Burmy/2.jpg
#   inflating: images/images/Burmy/3.jpg
#   inflating: images/images/Burmy/4.jpg
#   inflating: images/images/Burmy/5.jpg
#   inflating: images/images/Butterfree/0.jpg
#   inflating: images/images/Butterfree/1.jpg
#   inflating: images/images/Butterfree/2.jpg
#   inflating: images/images/Butterfree/3.jpg
#   inflating: images/images/Butterfree/4.jpg
#   inflating: images/images/Butterfree/5.jpg
#   inflating: images/images/Buzzwole/0.jpg
#   inflating: images/images/Buzzwole/1.jpg
#   inflating: images/images/Cacnea/0.jpg
#   inflating: images/images/Cacnea/1.jpg
#   inflating: images/images/Cacturne/0.jpg
#   inflating: images/images/Cacturne/1.jpg
#   inflating: images/images/Calyrex/0.jpg
#   inflating: images/images/Calyrex/1.jpg
#   inflating: images/images/Calyrex/2.jpg
#   inflating: images/images/Camerupt/0.jpg
#   inflating: images/images/Camerupt/1.jpg
#   inflating: images/images/Camerupt/2.jpg
#   inflating: images/images/Camerupt/3.jpg
#   inflating: images/images/Carbink/0.jpg
#   inflating: images/images/Carbink/1.jpg
#   inflating: images/images/Carkol/0.jpg
#   inflating: images/images/Carnivine/0.jpg
#   inflating: images/images/Carnivine/1.jpg
#   inflating: images/images/Carracosta/0.jpg
#   inflating: images/images/Carracosta/1.jpg
#   inflating: images/images/Carvanha/0.jpg
#   inflating: images/images/Carvanha/1.jpg
#   inflating: images/images/Cascoon/0.jpg
#   inflating: images/images/Cascoon/1.jpg
#   inflating: images/images/Castform/0.jpg
#   inflating: images/images/Castform/1.jpg
#   inflating: images/images/Castform/2.jpg
#   inflating: images/images/Castform/3.jpg
#   inflating: images/images/Castform/4.jpg
#   inflating: images/images/Caterpie/0.jpg
#   inflating: images/images/Caterpie/1.jpg
#   inflating: images/images/Caterpie/2.jpg
#   inflating: images/images/Caterpie/3.jpg
#   inflating: images/images/Celebi/0.jpg
#   inflating: images/images/Celebi/1.jpg
#   inflating: images/images/Celebi/2.jpg
#   inflating: images/images/Celesteela/0.jpg
#   inflating: images/images/Celesteela/1.jpg
#   inflating: images/images/Centiskorch/0.jpg
#   inflating: images/images/Centiskorch/1.jpg
#   inflating: images/images/Chandelure/0.jpg
#   inflating: images/images/Chandelure/1.jpg
#   inflating: images/images/Chansey/0.jpg
#   inflating: images/images/Chansey/1.jpg
#   inflating: images/images/Chansey/2.jpg
#   inflating: images/images/Chansey/3.jpg
#   inflating: images/images/Charizard/0.jpg
#   inflating: images/images/Charizard/1.jpg
#   inflating: images/images/Charizard/2.jpg
#   inflating: images/images/Charizard/3.jpg
#   inflating: images/images/Charizard/4.jpg
#   inflating: images/images/Charjabug/0.jpg
#   inflating: images/images/Charjabug/1.jpg
#   inflating: images/images/Charmander/0.jpg
#   inflating: images/images/Charmander/1.jpg
#   inflating: images/images/Charmander/2.jpg
#   inflating: images/images/Charmander/3.jpg
#   inflating: images/images/Charmeleon/0.jpg
#   inflating: images/images/Charmeleon/1.jpg
#   inflating: images/images/Charmeleon/2.jpg
#   inflating: images/images/Chatot/0.jpg
#   inflating: images/images/Chatot/1.jpg
#   inflating: images/images/Cherrim/0.jpg
#   inflating: images/images/Cherrim/1.jpg
#   inflating: images/images/Cherrim/2.jpg
#   inflating: images/images/Cherrim/3.jpg
#   inflating: images/images/Cherubi/0.jpg
#   inflating: images/images/Cherubi/1.jpg
#   inflating: images/images/Chesnaught/0.jpg
#   inflating: images/images/Chesnaught/1.jpg
#   inflating: images/images/Chespin/0.jpg
#   inflating: images/images/Chespin/1.jpg
#   inflating: images/images/Chewtle/0.jpg
#   inflating: images/images/Chikorita/0.jpg
#   inflating: images/images/Chikorita/1.jpg
#   inflating: images/images/Chikorita/2.jpg
#   inflating: images/images/Chimchar/0.jpg
#   inflating: images/images/Chimchar/1.jpg
#   inflating: images/images/Chimchar/2.jpg
#   inflating: images/images/Chimecho/0.jpg
#   inflating: images/images/Chimecho/1.jpg
#   inflating: images/images/Chinchou/0.jpg
#   inflating: images/images/Chinchou/1.jpg
#   inflating: images/images/Chinchou/2.jpg
#   inflating: images/images/Chingling/0.jpg
#   inflating: images/images/Chingling/1.jpg
#   inflating: images/images/Cinccino/0.jpg
#   inflating: images/images/Cinccino/1.jpg
#   inflating: images/images/Cinderace/0.jpg
#   inflating: images/images/Cinderace/1.jpg
#   inflating: images/images/Cinderace/2.jpg
#   inflating: images/images/Clamperl/0.jpg
#   inflating: images/images/Clamperl/1.jpg
#   inflating: images/images/Clauncher/0.jpg
#   inflating: images/images/Clauncher/1.jpg
#   inflating: images/images/Clawitzer/0.jpg
#   inflating: images/images/Clawitzer/1.jpg
#   inflating: images/images/Claydol/0.jpg
#   inflating: images/images/Claydol/1.jpg
#   inflating: images/images/Clefable/0.jpg
#   inflating: images/images/Clefable/1.jpg
#   inflating: images/images/Clefable/2.jpg
#   inflating: images/images/Clefable/3.jpg
#   inflating: images/images/Clefairy/0.jpg
#   inflating: images/images/Clefairy/1.jpg
#   inflating: images/images/Clefairy/2.jpg
#   inflating: images/images/Clefairy/3.jpg
#   inflating: images/images/Cleffa/0.jpg
#   inflating: images/images/Cleffa/1.jpg
#   inflating: images/images/Cleffa/2.jpg
#   inflating: images/images/Clobbopus/0.jpg
#   inflating: images/images/Cloyster/0.jpg
#   inflating: images/images/Cloyster/1.jpg
#   inflating: images/images/Cloyster/2.jpg
#   inflating: images/images/Cloyster/3.jpg
#   inflating: images/images/Coalossal/0.jpg
#   inflating: images/images/Coalossal/1.jpg
#   inflating: images/images/Cobalion/0.jpg
#   inflating: images/images/Cobalion/1.jpg
#   inflating: images/images/Cofagrigus/0.jpg
#   inflating: images/images/Cofagrigus/1.jpg
#   inflating: images/images/Combee/0.jpg
#   inflating: images/images/Combee/1.jpg
#   inflating: images/images/Combusken/0.jpg
#   inflating: images/images/Combusken/1.jpg
#   inflating: images/images/Comfey/0.jpg
#   inflating: images/images/Comfey/1.jpg
#   inflating: images/images/Conkeldurr/0.jpg
#   inflating: images/images/Conkeldurr/1.jpg
#   inflating: images/images/Copperajah/0.jpg
#   inflating: images/images/Copperajah/1.jpg
#   inflating: images/images/Corphish/0.jpg
#   inflating: images/images/Corphish/1.jpg
#   inflating: images/images/Corsola/0.jpg
#   inflating: images/images/Corsola/1.jpg
#   inflating: images/images/Corsola/2.jpg
#   inflating: images/images/Corsola/3.jpg
#   inflating: images/images/Corviknight/0.jpg
#   inflating: images/images/Corviknight/1.jpg
#   inflating: images/images/Corvisquire/0.jpg
#   inflating: images/images/Cosmoem/0.jpg
#   inflating: images/images/Cosmoem/1.jpg
#   inflating: images/images/Cosmog/0.jpg
#   inflating: images/images/Cosmog/1.jpg
#   inflating: images/images/Cottonee/0.jpg
#   inflating: images/images/Cottonee/1.jpg
#   inflating: images/images/Crabominable/0.jpg
#   inflating: images/images/Crabominable/1.jpg
#   inflating: images/images/Crabrawler/0.jpg
#   inflating: images/images/Crabrawler/1.jpg
#   inflating: images/images/Cradily/0.jpg
#   inflating: images/images/Cradily/1.jpg
#   inflating: images/images/Cramorant/0.jpg
#   inflating: images/images/Cramorant/1.jpg
#   inflating: images/images/Cranidos/0.jpg
#   inflating: images/images/Cranidos/1.jpg
#   inflating: images/images/Crawdaunt/0.jpg
#   inflating: images/images/Crawdaunt/1.jpg
#   inflating: images/images/Cresselia/0.jpg
#   inflating: images/images/Cresselia/1.jpg
#   inflating: images/images/Croagunk/0.jpg
#   inflating: images/images/Croagunk/1.jpg
#   inflating: images/images/Crobat/0.jpg
#   inflating: images/images/Crobat/1.jpg
#   inflating: images/images/Crobat/2.jpg
#   inflating: images/images/Croconaw/0.jpg
#   inflating: images/images/Croconaw/1.jpg
#   inflating: images/images/Croconaw/2.jpg
#   inflating: images/images/Crustle/0.jpg
#   inflating: images/images/Crustle/1.jpg
#   inflating: images/images/Cryogonal/0.jpg
#   inflating: images/images/Cryogonal/1.jpg
#   inflating: images/images/Cubchoo/0.jpg
#   inflating: images/images/Cubchoo/1.jpg
#   inflating: images/images/Cubone/0.jpg
#   inflating: images/images/Cubone/1.jpg
#   inflating: images/images/Cubone/2.jpg
#   inflating: images/images/Cubone/3.jpg
#   inflating: images/images/Cufant/0.jpg
#   inflating: images/images/Cursola/0.jpg
#   inflating: images/images/Cutiefly/0.jpg
#   inflating: images/images/Cutiefly/1.jpg
#   inflating: images/images/Cyndaquil/0.jpg
#   inflating: images/images/Cyndaquil/1.jpg
#   inflating: images/images/Cyndaquil/2.jpg
#   inflating: images/images/Darkrai/0.jpg
#   inflating: images/images/Darkrai/1.jpg
#   inflating: images/images/Darmanitan/0.jpg
#   inflating: images/images/Darmanitan/1.jpg
#   inflating: images/images/Darmanitan/2.jpg
#   inflating: images/images/Darmanitan/3.jpg
#   inflating: images/images/Darmanitan/4.jpg
#   inflating: images/images/Darmanitan/5.jpg
#   inflating: images/images/Dartrix/0.jpg
#   inflating: images/images/Dartrix/1.jpg
#   inflating: images/images/Dartrix/2.jpg
#   inflating: images/images/Darumaka/0.jpg
#   inflating: images/images/Darumaka/1.jpg
#   inflating: images/images/Darumaka/2.jpg
#   inflating: images/images/Decidueye/0.jpg
#   inflating: images/images/Decidueye/1.jpg
#   inflating: images/images/Decidueye/2.jpg
#   inflating: images/images/Dedenne/0.jpg
#   inflating: images/images/Dedenne/1.jpg
#   inflating: images/images/Deerling/0.jpg
#   inflating: images/images/Deerling/1.jpg
#   inflating: images/images/Deerling/2.jpg
#   inflating: images/images/Deerling/3.jpg
#   inflating: images/images/Deerling/4.jpg
#   inflating: images/images/Deerling/5.jpg
#   inflating: images/images/Deino/0.jpg
#   inflating: images/images/Deino/1.jpg
#   inflating: images/images/Delcatty/0.jpg
#   inflating: images/images/Delcatty/1.jpg
#   inflating: images/images/Delibird/0.jpg
#   inflating: images/images/Delibird/1.jpg
#   inflating: images/images/Delibird/2.jpg
#   inflating: images/images/Delphox/0.jpg
#   inflating: images/images/Delphox/1.jpg
#   inflating: images/images/Deoxys/0.jpg
#   inflating: images/images/Deoxys/1.jpg
#   inflating: images/images/Deoxys/2.jpg
#   inflating: images/images/Deoxys/3.jpg
#   inflating: images/images/Deoxys/4.jpg
#   inflating: images/images/Deoxys/5.jpg
#   inflating: images/images/Dewgong/0.jpg
#   inflating: images/images/Dewgong/1.jpg
#   inflating: images/images/Dewgong/2.jpg
#   inflating: images/images/Dewgong/3.jpg
#   inflating: images/images/Dewott/0.jpg
#   inflating: images/images/Dewott/1.jpg
#   inflating: images/images/Dewpider/0.jpg
#   inflating: images/images/Dewpider/1.jpg
#   inflating: images/images/Dhelmise/0.jpg
#   inflating: images/images/Dhelmise/1.jpg
#   inflating: images/images/Dialga/0.jpg
#   inflating: images/images/Dialga/1.jpg
#   inflating: images/images/Dialga/2.jpg
#   inflating: images/images/Dialga/3.jpg
#   inflating: images/images/Diancie/0.jpg
#   inflating: images/images/Diancie/1.jpg
#   inflating: images/images/Diancie/2.jpg
#   inflating: images/images/Diancie/3.jpg
#   inflating: images/images/Diancie/4.jpg
#   inflating: images/images/Diggersby/0.jpg
#   inflating: images/images/Diggersby/1.jpg
#   inflating: images/images/Diglett/0.jpg
#   inflating: images/images/Diglett/1.jpg
#   inflating: images/images/Diglett/2.jpg
#   inflating: images/images/Diglett/3.jpg
#   inflating: images/images/Diglett/4.jpg
#   inflating: images/images/Diglett/5.jpg
#   inflating: images/images/Ditto/0.jpg
#   inflating: images/images/Ditto/1.jpg
#   inflating: images/images/Ditto/2.jpg
#   inflating: images/images/Ditto/3.jpg
#   inflating: images/images/Dodrio/0.jpg
#   inflating: images/images/Dodrio/1.jpg
#   inflating: images/images/Dodrio/2.jpg
#   inflating: images/images/Dodrio/3.jpg
#   inflating: images/images/Doduo/0.jpg
#   inflating: images/images/Doduo/1.jpg
#   inflating: images/images/Doduo/2.jpg
#   inflating: images/images/Doduo/3.jpg
#   inflating: images/images/Donphan/0.jpg
#   inflating: images/images/Donphan/1.jpg
#   inflating: images/images/Donphan/2.jpg
#   inflating: images/images/Dottler/0.jpg
#   inflating: images/images/Doublade/0.jpg
#   inflating: images/images/Doublade/1.jpg
#   inflating: images/images/Dracovish/0.jpg
#   inflating: images/images/Dracozolt/0.jpg
#   inflating: images/images/Dragalge/0.jpg
#   inflating: images/images/Dragalge/1.jpg
#   inflating: images/images/Dragapult/0.jpg
#   inflating: images/images/Dragonair/0.jpg
#   inflating: images/images/Dragonair/1.jpg
#   inflating: images/images/Dragonair/2.jpg
#   inflating: images/images/Dragonair/3.jpg
#   inflating: images/images/Dragonite/0.jpg
#   inflating: images/images/Dragonite/1.jpg
#   inflating: images/images/Dragonite/2.jpg
#   inflating: images/images/Dragonite/3.jpg
#   inflating: images/images/Drakloak/0.jpg
#   inflating: images/images/Drampa/0.jpg
#   inflating: images/images/Drampa/1.jpg
#   inflating: images/images/Drapion/0.jpg
#   inflating: images/images/Drapion/1.jpg
#   inflating: images/images/Dratini/0.jpg
#   inflating: images/images/Dratini/1.jpg
#   inflating: images/images/Dratini/2.jpg
#   inflating: images/images/Dratini/3.jpg
#   inflating: images/images/Drednaw/0.jpg
#   inflating: images/images/Drednaw/1.jpg
#   inflating: images/images/Dreepy/0.jpg
#   inflating: images/images/Drifblim/0.jpg
#   inflating: images/images/Drifblim/1.jpg
#   inflating: images/images/Drifloon/0.jpg
#   inflating: images/images/Drifloon/1.jpg
#   inflating: images/images/Drilbur/0.jpg
#   inflating: images/images/Drilbur/1.jpg
#   inflating: images/images/Drizzile/0.jpg
#   inflating: images/images/Drowzee/0.jpg
#   inflating: images/images/Drowzee/1.jpg
#   inflating: images/images/Drowzee/2.jpg
#   inflating: images/images/Drowzee/3.jpg
#   inflating: images/images/Druddigon/0.jpg
#   inflating: images/images/Druddigon/1.jpg
#   inflating: images/images/Dubwool/0.jpg
#   inflating: images/images/Ducklett/0.jpg
#   inflating: images/images/Ducklett/1.jpg
#   inflating: images/images/Dugtrio/0.jpg
#   inflating: images/images/Dugtrio/1.jpg
#   inflating: images/images/Dugtrio/2.jpg
#   inflating: images/images/Dugtrio/3.jpg
#   inflating: images/images/Dugtrio/4.jpg
#   inflating: images/images/Dugtrio/5.jpg
#   inflating: images/images/Dunsparce/0.jpg
#   inflating: images/images/Dunsparce/1.jpg
#   inflating: images/images/Dunsparce/2.jpg
#   inflating: images/images/Duosion/0.jpg
#   inflating: images/images/Duosion/1.jpg
#   inflating: images/images/Duraludon/0.jpg
#   inflating: images/images/Duraludon/1.jpg
#   inflating: images/images/Durant/0.jpg
#   inflating: images/images/Durant/1.jpg
#   inflating: images/images/Dusclops/0.jpg
#   inflating: images/images/Dusclops/1.jpg
#   inflating: images/images/Dusknoir/0.jpg
#   inflating: images/images/Dusknoir/1.jpg
#   inflating: images/images/Duskull/0.jpg
#   inflating: images/images/Duskull/1.jpg
#   inflating: images/images/Dustox/0.jpg
#   inflating: images/images/Dustox/1.jpg
#   inflating: images/images/Dwebble/0.jpg
#   inflating: images/images/Dwebble/1.jpg
#   inflating: images/images/Eelektrik/0.jpg
#   inflating: images/images/Eelektrik/1.jpg
#   inflating: images/images/Eelektross/0.jpg
#   inflating: images/images/Eelektross/1.jpg
#   inflating: images/images/Eevee/0.jpg
#   inflating: images/images/Eevee/1.jpg
#   inflating: images/images/Eevee/2.jpg
#   inflating: images/images/Eevee/3.jpg
#   inflating: images/images/Eevee/4.jpg
#   inflating: images/images/Eiscue/0.jpg
#   inflating: images/images/Eiscue/1.jpg
#   inflating: images/images/Ekans/0.jpg
#   inflating: images/images/Ekans/1.jpg
#   inflating: images/images/Ekans/2.jpg
#   inflating: images/images/Ekans/3.jpg
#   inflating: images/images/Eldegoss/0.jpg
#   inflating: images/images/Electabuzz/0.jpg
#   inflating: images/images/Electabuzz/1.jpg
#   inflating: images/images/Electabuzz/2.jpg
#   inflating: images/images/Electabuzz/3.jpg
#   inflating: images/images/Electivire/0.jpg
#   inflating: images/images/Electivire/1.jpg
#   inflating: images/images/Electrike/0.jpg
#   inflating: images/images/Electrike/1.jpg
#   inflating: images/images/Electrode/0.jpg
#   inflating: images/images/Electrode/1.jpg
#   inflating: images/images/Electrode/2.jpg
#   inflating: images/images/Electrode/3.jpg
#   inflating: images/images/Elekid/0.jpg
#   inflating: images/images/Elekid/1.jpg
#   inflating: images/images/Elekid/2.jpg
#   inflating: images/images/Elgyem/0.jpg
#   inflating: images/images/Elgyem/1.jpg
#   inflating: images/images/Emboar/0.jpg
#   inflating: images/images/Emboar/1.jpg
#   inflating: images/images/Emolga/0.jpg
#   inflating: images/images/Emolga/1.jpg
#   inflating: images/images/Empoleon/0.jpg
#   inflating: images/images/Empoleon/1.jpg
#   inflating: images/images/Entei/0.jpg
#   inflating: images/images/Entei/1.jpg
#   inflating: images/images/Entei/2.jpg
#   inflating: images/images/Entei/3.jpg
#   inflating: images/images/Escavalier/0.jpg
#   inflating: images/images/Escavalier/1.jpg
#   inflating: images/images/Espeon/0.jpg
#   inflating: images/images/Espeon/1.jpg
#   inflating: images/images/Espeon/2.jpg
#   inflating: images/images/Espurr/0.jpg
#   inflating: images/images/Espurr/1.jpg
#   inflating: images/images/Eternatus/0.jpg
#   inflating: images/images/Eternatus/1.jpg
#   inflating: images/images/Excadrill/0.jpg
#   inflating: images/images/Excadrill/1.jpg
#   inflating: images/images/Exeggcute/0.jpg
#   inflating: images/images/Exeggcute/1.jpg
#   inflating: images/images/Exeggcute/2.jpg
#   inflating: images/images/Exeggcute/3.jpg
#   inflating: images/images/Exeggutor/0.jpg
#   inflating: images/images/Exeggutor/1.jpg
#   inflating: images/images/Exeggutor/2.jpg
#   inflating: images/images/Exploud/0.jpg
#   inflating: images/images/Exploud/1.jpg
#   inflating: images/images/Falinks/0.jpg
#   inflating: images/images/Farfetch'd/0.jpg
#   inflating: images/images/Farfetch'd/1.jpg
#   inflating: images/images/Farfetch'd/2.jpg
#   inflating: images/images/Farfetch'd/3.jpg
#   inflating: images/images/Farfetch'd/4.jpg
#   inflating: images/images/Fearow/0.jpg
#   inflating: images/images/Fearow/1.jpg
#   inflating: images/images/Fearow/2.jpg
#   inflating: images/images/Fearow/3.jpg
#   inflating: images/images/Feebas/0.jpg
#   inflating: images/images/Feebas/1.jpg
#   inflating: images/images/Fennekin/0.jpg
#   inflating: images/images/Fennekin/1.jpg
#   inflating: images/images/Feraligatr/0.jpg
#   inflating: images/images/Feraligatr/1.jpg
#   inflating: images/images/Feraligatr/2.jpg
#   inflating: images/images/Ferroseed/0.jpg
#   inflating: images/images/Ferroseed/1.jpg
#   inflating: images/images/Ferrothorn/0.jpg
#   inflating: images/images/Ferrothorn/1.jpg
#   inflating: images/images/Finneon/0.jpg
#   inflating: images/images/Finneon/1.jpg
#   inflating: images/images/Flaaffy/0.jpg
#   inflating: images/images/Flaaffy/1.jpg
#   inflating: images/images/Flaaffy/2.jpg
#   inflating: images/images/Flab├йb├й/0.jpg
#   inflating: images/images/Flab├йb├й/1.jpg
#   inflating: images/images/Flab├йb├й/2.jpg
#   inflating: images/images/Flab├йb├й/3.jpg
#   inflating: images/images/Flab├йb├й/4.jpg
#   inflating: images/images/Flab├йb├й/5.jpg
#   inflating: images/images/Flapple/0.jpg
#   inflating: images/images/Flapple/1.jpg
#   inflating: images/images/Flareon/0.jpg
#   inflating: images/images/Flareon/1.jpg
#   inflating: images/images/Flareon/2.jpg
#   inflating: images/images/Flareon/3.jpg
#   inflating: images/images/Fletchinder/0.jpg
#   inflating: images/images/Fletchinder/1.jpg
#   inflating: images/images/Fletchling/0.jpg
#   inflating: images/images/Fletchling/1.jpg
#   inflating: images/images/Floatzel/0.jpg
#   inflating: images/images/Floatzel/1.jpg
#   inflating: images/images/Floette/0.jpg
#   inflating: images/images/Floette/1.jpg
#   inflating: images/images/Floette/2.jpg
#   inflating: images/images/Floette/3.jpg
#   inflating: images/images/Floette/4.jpg
#   inflating: images/images/Floette/5.jpg
#   inflating: images/images/Florges/0.jpg
#   inflating: images/images/Florges/1.jpg
#   inflating: images/images/Florges/2.jpg
#   inflating: images/images/Florges/3.jpg
#   inflating: images/images/Florges/4.jpg
#   inflating: images/images/Florges/5.jpg
#   inflating: images/images/Flygon/0.jpg
#   inflating: images/images/Flygon/1.jpg
#   inflating: images/images/Fomantis/0.jpg
#   inflating: images/images/Fomantis/1.jpg
#   inflating: images/images/Foongus/0.jpg
#   inflating: images/images/Foongus/1.jpg
#   inflating: images/images/Forretress/0.jpg
#   inflating: images/images/Forretress/1.jpg
#   inflating: images/images/Forretress/2.jpg
#   inflating: images/images/Fraxure/0.jpg
#   inflating: images/images/Fraxure/1.jpg
#   inflating: images/images/Frillish/0.jpg
#   inflating: images/images/Frillish/1.jpg
#   inflating: images/images/Frillish/2.jpg
#   inflating: images/images/Frillish/3.jpg
#   inflating: images/images/Froakie/0.jpg
#   inflating: images/images/Froakie/1.jpg
#   inflating: images/images/Frogadier/0.jpg
#   inflating: images/images/Frogadier/1.jpg
#   inflating: images/images/Froslass/0.jpg
#   inflating: images/images/Froslass/1.jpg
#   inflating: images/images/Frosmoth/0.jpg
#   inflating: images/images/Furfrou/0.jpg
#   inflating: images/images/Furfrou/1.jpg
#   inflating: images/images/Furfrou/2.jpg
#   inflating: images/images/Furfrou/3.jpg
#   inflating: images/images/Furfrou/4.jpg
#   inflating: images/images/Furfrou/5.jpg
#   inflating: images/images/Furret/0.jpg
#   inflating: images/images/Furret/1.jpg
#   inflating: images/images/Furret/2.jpg
#   inflating: images/images/Gabite/0.jpg
#   inflating: images/images/Gabite/1.jpg
#   inflating: images/images/Gallade/0.jpg
#   inflating: images/images/Gallade/1.jpg
#   inflating: images/images/Gallade/2.jpg
#   inflating: images/images/Gallade/3.jpg
#   inflating: images/images/Galvantula/0.jpg
#   inflating: images/images/Galvantula/1.jpg
#   inflating: images/images/Garbodor/0.jpg
#   inflating: images/images/Garbodor/1.jpg
#   inflating: images/images/Garbodor/2.jpg
#   inflating: images/images/Garchomp/0.jpg
#   inflating: images/images/Garchomp/1.jpg
#   inflating: images/images/Garchomp/2.jpg
#   inflating: images/images/Garchomp/3.jpg
#   inflating: images/images/Gardevoir/0.jpg
#   inflating: images/images/Gardevoir/1.jpg
#   inflating: images/images/Gardevoir/2.jpg
#   inflating: images/images/Gardevoir/3.jpg
#   inflating: images/images/Gastly/0.jpg
#   inflating: images/images/Gastly/1.jpg
#   inflating: images/images/Gastly/2.jpg
#   inflating: images/images/Gastly/3.jpg
#   inflating: images/images/Gastrodon/0.jpg
#   inflating: images/images/Gastrodon/1.jpg
#   inflating: images/images/Gastrodon/2.jpg
#   inflating: images/images/Gastrodon/3.jpg
#   inflating: images/images/Genesect/0.jpg
#   inflating: images/images/Genesect/1.jpg
#   inflating: images/images/Genesect/2.jpg
#   inflating: images/images/Genesect/3.jpg
#   inflating: images/images/Genesect/4.jpg
#   inflating: images/images/Genesect/5.jpg
#   inflating: images/images/Gengar/0.jpg
#   inflating: images/images/Gengar/1.jpg
#   inflating: images/images/Gengar/2.jpg
#   inflating: images/images/Gengar/3.jpg
#   inflating: images/images/Gengar/4.jpg
#   inflating: images/images/Gengar/5.jpg
#   inflating: images/images/Geodude/0.jpg
#   inflating: images/images/Geodude/1.jpg
#   inflating: images/images/Geodude/2.jpg
#   inflating: images/images/Geodude/3.jpg
#   inflating: images/images/Geodude/4.jpg
#   inflating: images/images/Geodude/5.jpg
#   inflating: images/images/Gible/0.jpg
#   inflating: images/images/Gible/1.jpg
#   inflating: images/images/Gigalith/0.jpg
#   inflating: images/images/Gigalith/1.jpg
#   inflating: images/images/Girafarig/0.jpg
#   inflating: images/images/Girafarig/1.jpg
#   inflating: images/images/Girafarig/2.jpg
#   inflating: images/images/Giratina/0.jpg
#   inflating: images/images/Giratina/1.jpg
#   inflating: images/images/Giratina/2.jpg
#   inflating: images/images/Giratina/3.jpg
#   inflating: images/images/Giratina/4.jpg
#   inflating: images/images/Glaceon/0.jpg
#   inflating: images/images/Glaceon/1.jpg
#   inflating: images/images/Glalie/0.jpg
#   inflating: images/images/Glalie/1.jpg
#   inflating: images/images/Glalie/2.jpg
#   inflating: images/images/Glalie/3.jpg
#   inflating: images/images/Glameow/0.jpg
#   inflating: images/images/Glameow/1.jpg
#   inflating: images/images/Glastrier/0.jpg
#   inflating: images/images/Gligar/0.jpg
#   inflating: images/images/Gligar/1.jpg
#   inflating: images/images/Gligar/2.jpg
#   inflating: images/images/Gliscor/0.jpg
#   inflating: images/images/Gliscor/1.jpg
#   inflating: images/images/Gloom/0.jpg
#   inflating: images/images/Gloom/1.jpg
#   inflating: images/images/Gloom/2.jpg
#   inflating: images/images/Gloom/3.jpg
#   inflating: images/images/Gogoat/0.jpg
#   inflating: images/images/Gogoat/1.jpg
#   inflating: images/images/Golbat/0.jpg
#   inflating: images/images/Golbat/1.jpg
#   inflating: images/images/Golbat/2.jpg
#   inflating: images/images/Golbat/3.jpg
#   inflating: images/images/Goldeen/0.jpg
#   inflating: images/images/Goldeen/1.jpg
#   inflating: images/images/Goldeen/2.jpg
#   inflating: images/images/Goldeen/3.jpg
#   inflating: images/images/Golduck/0.jpg
#   inflating: images/images/Golduck/1.jpg
#   inflating: images/images/Golduck/2.jpg
#   inflating: images/images/Golduck/3.jpg
#   inflating: images/images/Golem/0.jpg
#   inflating: images/images/Golem/1.jpg
#   inflating: images/images/Golem/2.jpg
#   inflating: images/images/Golem/3.jpg
#   inflating: images/images/Golem/4.jpg
#   inflating: images/images/Golem/5.jpg
#   inflating: images/images/Golett/0.jpg
#   inflating: images/images/Golett/1.jpg
#   inflating: images/images/Golisopod/0.jpg
#   inflating: images/images/Golisopod/1.jpg
#   inflating: images/images/Golurk/0.jpg
#   inflating: images/images/Golurk/1.jpg
#   inflating: images/images/Goodra/0.jpg
#   inflating: images/images/Goodra/1.jpg
#   inflating: images/images/Goomy/0.jpg
#   inflating: images/images/Goomy/1.jpg
#   inflating: images/images/Gorebyss/0.jpg
#   inflating: images/images/Gorebyss/1.jpg
#   inflating: images/images/Gossifleur/0.jpg
#   inflating: images/images/Gothita/0.jpg
#   inflating: images/images/Gothita/1.jpg
#   inflating: images/images/Gothitelle/0.jpg
#   inflating: images/images/Gothitelle/1.jpg
#   inflating: images/images/Gothorita/0.jpg
#   inflating: images/images/Gothorita/1.jpg
#   inflating: images/images/Gourgeist/0.jpg
#   inflating: images/images/Gourgeist/1.jpg
#   inflating: images/images/Gourgeist/2.jpg
#   inflating: images/images/Gourgeist/3.jpg
#   inflating: images/images/Gourgeist/4.jpg
#   inflating: images/images/Granbull/0.jpg
#   inflating: images/images/Granbull/1.jpg
#   inflating: images/images/Granbull/2.jpg
#   inflating: images/images/Grapploct/0.jpg
#   inflating: images/images/Graveler/0.jpg
#   inflating: images/images/Graveler/1.jpg
#   inflating: images/images/Graveler/2.jpg
#   inflating: images/images/Graveler/3.jpg
#   inflating: images/images/Graveler/4.jpg
#   inflating: images/images/Graveler/5.jpg
#   inflating: images/images/Greedent/0.jpg
#   inflating: images/images/Greninja/0.jpg
#   inflating: images/images/Greninja/1.jpg
#   inflating: images/images/Greninja/2.jpg
#   inflating: images/images/Greninja/3.jpg
#   inflating: images/images/Greninja/4.jpg
#   inflating: images/images/Grimer/0.jpg
#   inflating: images/images/Grimer/1.jpg
#   inflating: images/images/Grimer/2.jpg
#   inflating: images/images/Grimer/3.jpg
#   inflating: images/images/Grimer/4.jpg
#   inflating: images/images/Grimer/5.jpg
#   inflating: images/images/Grimmsnarl/0.jpg
#   inflating: images/images/Grimmsnarl/1.jpg
#   inflating: images/images/Grookey/0.jpg
#   inflating: images/images/Grookey/1.jpg
#   inflating: images/images/Grotle/0.jpg
#   inflating: images/images/Grotle/1.jpg
#   inflating: images/images/Groudon/0.jpg
#   inflating: images/images/Groudon/1.jpg
#   inflating: images/images/Groudon/2.jpg
#   inflating: images/images/Groudon/3.jpg
#   inflating: images/images/Groudon/4.jpg
#   inflating: images/images/Grovyle/0.jpg
#   inflating: images/images/Grovyle/1.jpg
#   inflating: images/images/Growlithe/0.jpg
#   inflating: images/images/Growlithe/1.jpg
#   inflating: images/images/Growlithe/2.jpg
#   inflating: images/images/Growlithe/3.jpg
#   inflating: images/images/Grubbin/0.jpg
#   inflating: images/images/Grubbin/1.jpg
#   inflating: images/images/Grumpig/0.jpg
#   inflating: images/images/Grumpig/1.jpg
#   inflating: images/images/Gulpin/0.jpg
#   inflating: images/images/Gulpin/1.jpg
#   inflating: images/images/Gumshoos/0.jpg
#   inflating: images/images/Gumshoos/1.jpg
#   inflating: images/images/Gurdurr/0.jpg
#   inflating: images/images/Gurdurr/1.jpg
#   inflating: images/images/Guzzlord/0.jpg
#   inflating: images/images/Guzzlord/1.jpg
#   inflating: images/images/Gyarados/0.jpg
#   inflating: images/images/Gyarados/1.jpg
#   inflating: images/images/Gyarados/2.jpg
#   inflating: images/images/Gyarados/3.jpg
#   inflating: images/images/Gyarados/4.jpg
#   inflating: images/images/Gyarados/5.jpg
#   inflating: images/images/Hakamo-o/0.jpg
#   inflating: images/images/Hakamo-o/1.jpg
#   inflating: images/images/Happiny/0.jpg
#   inflating: images/images/Happiny/1.jpg
#   inflating: images/images/Hariyama/0.jpg
#   inflating: images/images/Hariyama/1.jpg
#   inflating: images/images/Hatenna/0.jpg
#   inflating: images/images/Hatterene/0.jpg
#   inflating: images/images/Hatterene/1.jpg
#   inflating: images/images/Hattrem/0.jpg
#   inflating: images/images/Haunter/0.jpg
#   inflating: images/images/Haunter/1.jpg
#   inflating: images/images/Haunter/2.jpg
#   inflating: images/images/Haunter/3.jpg
#   inflating: images/images/Hawlucha/0.jpg
#   inflating: images/images/Hawlucha/1.jpg
#   inflating: images/images/Haxorus/0.jpg
#   inflating: images/images/Haxorus/1.jpg
#   inflating: images/images/Heatmor/0.jpg
#   inflating: images/images/Heatmor/1.jpg
#   inflating: images/images/Heatran/0.jpg
#   inflating: images/images/Heatran/1.jpg
#   inflating: images/images/Heatran/2.jpg
#   inflating: images/images/Heliolisk/0.jpg
#   inflating: images/images/Heliolisk/1.jpg
#   inflating: images/images/Helioptile/0.jpg
#   inflating: images/images/Helioptile/1.jpg
#   inflating: images/images/Heracross/0.jpg
#   inflating: images/images/Heracross/1.jpg
#   inflating: images/images/Heracross/2.jpg
#   inflating: images/images/Heracross/3.jpg
#   inflating: images/images/Heracross/4.jpg
#   inflating: images/images/Herdier/0.jpg
#   inflating: images/images/Herdier/1.jpg
#   inflating: images/images/Hippopotas/0.jpg
#   inflating: images/images/Hippopotas/1.jpg
#   inflating: images/images/Hippowdon/0.jpg
#   inflating: images/images/Hippowdon/1.jpg
#   inflating: images/images/Hitmonchan/0.jpg
#   inflating: images/images/Hitmonchan/1.jpg
#   inflating: images/images/Hitmonchan/2.jpg
#   inflating: images/images/Hitmonchan/3.jpg
#   inflating: images/images/Hitmonlee/0.jpg
#   inflating: images/images/Hitmonlee/1.jpg
#   inflating: images/images/Hitmonlee/2.jpg
#   inflating: images/images/Hitmonlee/3.jpg
#   inflating: images/images/Hitmontop/0.jpg
#   inflating: images/images/Hitmontop/1.jpg
#   inflating: images/images/Hitmontop/2.jpg
#   inflating: images/images/Ho-oh/0.jpg
#   inflating: images/images/Ho-oh/1.jpg
#   inflating: images/images/Ho-oh/2.jpg
#   inflating: images/images/Ho-oh/3.jpg
#   inflating: images/images/Ho-oh/4.jpg
#   inflating: images/images/Honchkrow/0.jpg
#   inflating: images/images/Honchkrow/1.jpg
#   inflating: images/images/Honedge/0.jpg
#   inflating: images/images/Honedge/1.jpg
#   inflating: images/images/Hoopa/0.jpg
#   inflating: images/images/Hoopa/1.jpg
#   inflating: images/images/Hoopa/2.jpg
#   inflating: images/images/Hoopa/3.jpg
#   inflating: images/images/Hoothoot/0.jpg
#   inflating: images/images/Hoothoot/1.jpg
#   inflating: images/images/Hoothoot/2.jpg
#   inflating: images/images/Hoppip/0.jpg
#   inflating: images/images/Hoppip/1.jpg
#   inflating: images/images/Hoppip/2.jpg
#   inflating: images/images/Horsea/0.jpg
#   inflating: images/images/Horsea/1.jpg
#   inflating: images/images/Horsea/2.jpg
#   inflating: images/images/Horsea/3.jpg
#   inflating: images/images/Houndoom/0.jpg
#   inflating: images/images/Houndoom/1.jpg
#   inflating: images/images/Houndoom/2.jpg
#   inflating: images/images/Houndoom/3.jpg
#   inflating: images/images/Houndoom/4.jpg
#   inflating: images/images/Houndour/0.jpg
#   inflating: images/images/Houndour/1.jpg
#   inflating: images/images/Houndour/2.jpg
#   inflating: images/images/Huntail/0.jpg
#   inflating: images/images/Huntail/1.jpg
#   inflating: images/images/Hydreigon/0.jpg
#   inflating: images/images/Hydreigon/1.jpg
#   inflating: images/images/Hypno/0.jpg
#   inflating: images/images/Hypno/1.jpg
#   inflating: images/images/Hypno/2.jpg
#   inflating: images/images/Hypno/3.jpg
#   inflating: images/images/Igglybuff/0.jpg
#   inflating: images/images/Igglybuff/1.jpg
#   inflating: images/images/Igglybuff/2.jpg
#   inflating: images/images/Illumise/0.jpg
#   inflating: images/images/Illumise/1.jpg
#   inflating: images/images/Impidimp/0.jpg
#   inflating: images/images/Incineroar/0.jpg
#   inflating: images/images/Incineroar/1.jpg
#   inflating: images/images/Incineroar/2.jpg
#   inflating: images/images/Indeedee/0.jpg
#   inflating: images/images/Indeedee/1.jpg
#   inflating: images/images/Infernape/0.jpg
#   inflating: images/images/Infernape/1.jpg
#   inflating: images/images/Inkay/0.jpg
#   inflating: images/images/Inkay/1.jpg
#   inflating: images/images/Inteleon/0.jpg
#   inflating: images/images/Inteleon/1.jpg
#   inflating: images/images/Inteleon/2.jpg
#   inflating: images/images/Ivysaur/0.jpg
#   inflating: images/images/Ivysaur/1.jpg
#   inflating: images/images/Ivysaur/2.jpg
#   inflating: images/images/Ivysaur/3.jpg
#   inflating: images/images/Jangmo-o/0.jpg
#   inflating: images/images/Jangmo-o/1.jpg
#   inflating: images/images/Jellicent/0.jpg
#   inflating: images/images/Jellicent/1.jpg
#   inflating: images/images/Jellicent/2.jpg
#   inflating: images/images/Jellicent/3.jpg
#   inflating: images/images/Jigglypuff/0.jpg
#   inflating: images/images/Jigglypuff/1.jpg
#   inflating: images/images/Jigglypuff/2.jpg
#   inflating: images/images/Jigglypuff/3.jpg
#   inflating: images/images/Jirachi/0.jpg
#   inflating: images/images/Jirachi/1.jpg
#   inflating: images/images/Jolteon/0.jpg
#   inflating: images/images/Jolteon/1.jpg
#   inflating: images/images/Jolteon/2.jpg
#   inflating: images/images/Jolteon/3.jpg
#   inflating: images/images/Joltik/0.jpg
#   inflating: images/images/Joltik/1.jpg
#   inflating: images/images/Jumpluff/0.jpg
#   inflating: images/images/Jumpluff/1.jpg
#   inflating: images/images/Jumpluff/2.jpg
#   inflating: images/images/Jynx/0.jpg
#   inflating: images/images/Jynx/1.jpg
#   inflating: images/images/Jynx/2.jpg
#   inflating: images/images/Jynx/3.jpg
#   inflating: images/images/Kabuto/0.jpg
#   inflating: images/images/Kabuto/1.jpg
#   inflating: images/images/Kabuto/2.jpg
#   inflating: images/images/Kabuto/3.jpg
#   inflating: images/images/Kabutops/0.jpg
#   inflating: images/images/Kabutops/1.jpg
#   inflating: images/images/Kabutops/2.jpg
#   inflating: images/images/Kabutops/3.jpg
#   inflating: images/images/Kadabra/0.jpg
#   inflating: images/images/Kadabra/1.jpg
#   inflating: images/images/Kadabra/2.jpg
#   inflating: images/images/Kadabra/3.jpg
#   inflating: images/images/Kakuna/0.jpg
#   inflating: images/images/Kakuna/1.jpg
#   inflating: images/images/Kakuna/2.jpg
#   inflating: images/images/Kakuna/3.jpg
#   inflating: images/images/Kangaskhan/0.jpg
#   inflating: images/images/Kangaskhan/1.jpg
#   inflating: images/images/Kangaskhan/2.jpg
#   inflating: images/images/Kangaskhan/3.jpg
#   inflating: images/images/Kangaskhan/4.jpg
#   inflating: images/images/Kangaskhan/5.jpg
#   inflating: images/images/Karrablast/0.jpg
#   inflating: images/images/Karrablast/1.jpg
#   inflating: images/images/Kartana/0.jpg
#   inflating: images/images/Kartana/1.jpg
#   inflating: images/images/Kecleon/0.jpg
#   inflating: images/images/Kecleon/1.jpg
#   inflating: images/images/Keldeo/0.jpg
#   inflating: images/images/Keldeo/1.jpg
#   inflating: images/images/Keldeo/2.jpg
#   inflating: images/images/Keldeo/3.jpg
#   inflating: images/images/Kingdra/0.jpg
#   inflating: images/images/Kingdra/1.jpg
#   inflating: images/images/Kingdra/2.jpg
#   inflating: images/images/Kingler/0.jpg
#   inflating: images/images/Kingler/1.jpg
#   inflating: images/images/Kingler/2.jpg
#   inflating: images/images/Kingler/3.jpg
#   inflating: images/images/Kingler/4.jpg
#   inflating: images/images/Kirlia/0.jpg
#   inflating: images/images/Kirlia/1.jpg
#   inflating: images/images/Klang/0.jpg
#   inflating: images/images/Klang/1.jpg
#   inflating: images/images/Klefki/0.jpg
#   inflating: images/images/Klefki/1.jpg
#   inflating: images/images/Klink/0.jpg
#   inflating: images/images/Klink/1.jpg
#   inflating: images/images/Klinklang/0.jpg
#   inflating: images/images/Klinklang/1.jpg
#   inflating: images/images/Koffing/0.jpg
#   inflating: images/images/Koffing/1.jpg
#   inflating: images/images/Koffing/2.jpg
#   inflating: images/images/Koffing/3.jpg
#   inflating: images/images/Komala/0.jpg
#   inflating: images/images/Komala/1.jpg
#   inflating: images/images/Komala/2.jpg
#   inflating: images/images/Kommo-o/0.jpg
#   inflating: images/images/Kommo-o/1.jpg
#   inflating: images/images/Krabby/0.jpg
#   inflating: images/images/Krabby/1.jpg
#   inflating: images/images/Krabby/2.jpg
#   inflating: images/images/Krabby/3.jpg
#   inflating: images/images/Kricketot/0.jpg
#   inflating: images/images/Kricketot/1.jpg
#   inflating: images/images/Kricketune/0.jpg
#   inflating: images/images/Kricketune/1.jpg
# ...
#   inflating: images/images/Sylveon/0.jpg
#   inflating: images/images/Sylveon/1.jpg
#   inflating: images/images/Sylveon/2.jpg
#   inflating: images/images/Taillow/0.jpg
#   inflating: images/images/Taillow/1.jpg
#   inflating: images/images/Talonflame/0.jpg
#   inflating: images/images/Talonflame/1.jpg
#   inflating: images/images/Tangela/0.jpg
#   inflating: images/images/Tangela/1.jpg
#   inflating: images/images/Tangela/2.jpg
#   inflating: images/images/Tangela/3.jpg
#   inflating: images/images/Tangrowth/0.jpg
#   inflating: images/images/Tangrowth/1.jpg
#   inflating: images/images/Tapu Bulu/0.jpg
#   inflating: images/images/Tapu Bulu/1.jpg
#   inflating: images/images/Tapu Fini/0.jpg
#   inflating: images/images/Tapu Fini/1.jpg
#   inflating: images/images/Tapu Koko/0.jpg
#   inflating: images/images/Tapu Koko/1.jpg
#   inflating: images/images/Tapu Lele/0.jpg
#   inflating: images/images/Tapu Lele/1.jpg
#   inflating: images/images/Tauros/0.jpg
#   inflating: images/images/Tauros/1.jpg
#   inflating: images/images/Tauros/2.jpg
#   inflating: images/images/Tauros/3.jpg
#   inflating: images/images/Teddiursa/0.jpg
#   inflating: images/images/Teddiursa/1.jpg
#   inflating: images/images/Teddiursa/2.jpg
#   inflating: images/images/Tentacool/0.jpg
#   inflating: images/images/Tentacool/1.jpg
#   inflating: images/images/Tentacool/2.jpg
#   inflating: images/images/Tentacool/3.jpg
#   inflating: images/images/Tentacruel/0.jpg
#   inflating: images/images/Tentacruel/1.jpg
#   inflating: images/images/Tentacruel/2.jpg
#   inflating: images/images/Tentacruel/3.jpg
#   inflating: images/images/Tepig/0.jpg
#   inflating: images/images/Tepig/1.jpg
#   inflating: images/images/Tepig/2.jpg
#   inflating: images/images/Terrakion/0.jpg
#   inflating: images/images/Terrakion/1.jpg
#   inflating: images/images/Thievul/0.jpg
#   inflating: images/images/Throh/0.jpg
#   inflating: images/images/Throh/1.jpg
#   inflating: images/images/Thundurus/0.jpg
#   inflating: images/images/Thundurus/1.jpg
#   inflating: images/images/Thundurus/2.jpg
#   inflating: images/images/Thundurus/3.jpg
#   inflating: images/images/Thundurus/4.jpg
#   inflating: images/images/Thwackey/0.jpg
#   inflating: images/images/Timburr/0.jpg
#   inflating: images/images/Timburr/1.jpg
#   inflating: images/images/Tirtouga/0.jpg
#   inflating: images/images/Tirtouga/1.jpg
#   inflating: images/images/Togedemaru/0.jpg
#   inflating: images/images/Togedemaru/1.jpg
#   inflating: images/images/Togekiss/0.jpg
#   inflating: images/images/Togekiss/1.jpg
#   inflating: images/images/Togepi/0.jpg
#   inflating: images/images/Togepi/1.jpg
#   inflating: images/images/Togepi/2.jpg
#   inflating: images/images/Togetic/0.jpg
#   inflating: images/images/Togetic/1.jpg
#   inflating: images/images/Togetic/2.jpg
#   inflating: images/images/Torchic/0.jpg
#   inflating: images/images/Torchic/1.jpg
#   inflating: images/images/Torchic/2.jpg
#   inflating: images/images/Torchic/3.jpg
#   inflating: images/images/Torkoal/0.jpg
#   inflating: images/images/Torkoal/1.jpg
#   inflating: images/images/Tornadus/0.jpg
#   inflating: images/images/Tornadus/1.jpg
#   inflating: images/images/Tornadus/2.jpg
#   inflating: images/images/Tornadus/3.jpg
#   inflating: images/images/Tornadus/4.jpg
#   inflating: images/images/Torracat/0.jpg
#   inflating: images/images/Torracat/1.jpg
#   inflating: images/images/Torracat/2.jpg
#   inflating: images/images/Torterra/0.jpg
#   inflating: images/images/Torterra/1.jpg
#   inflating: images/images/Totodile/0.jpg
#   inflating: images/images/Totodile/1.jpg
#   inflating: images/images/Totodile/2.jpg
#   inflating: images/images/Toucannon/0.jpg
#   inflating: images/images/Toucannon/1.jpg
#   inflating: images/images/Toxapex/0.jpg
#   inflating: images/images/Toxapex/1.jpg
#   inflating: images/images/Toxel/0.jpg
#   inflating: images/images/Toxicroak/0.jpg
#   inflating: images/images/Toxicroak/1.jpg
#   inflating: images/images/Toxtricity/0.jpg
#   inflating: images/images/Toxtricity/1.jpg
#   inflating: images/images/Toxtricity/2.jpg
#   inflating: images/images/Toxtricity/3.jpg
#   inflating: images/images/Tranquill/0.jpg
#   inflating: images/images/Tranquill/1.jpg
#   inflating: images/images/Trapinch/0.jpg
#   inflating: images/images/Trapinch/1.jpg
#   inflating: images/images/Treecko/0.jpg
#   inflating: images/images/Treecko/1.jpg
#   inflating: images/images/Treecko/2.jpg
#   inflating: images/images/Treecko/3.jpg
#   inflating: images/images/Trevenant/0.jpg
#   inflating: images/images/Trevenant/1.jpg
#   inflating: images/images/Tropius/0.jpg
#   inflating: images/images/Tropius/1.jpg
#   inflating: images/images/Trubbish/0.jpg
#   inflating: images/images/Trubbish/1.jpg
#   inflating: images/images/Trumbeak/0.jpg
#   inflating: images/images/Trumbeak/1.jpg
#   inflating: images/images/Tsareena/0.jpg
#   inflating: images/images/Tsareena/1.jpg
#   inflating: images/images/Turtonator/0.jpg
#   inflating: images/images/Turtonator/1.jpg
#   inflating: images/images/Turtwig/0.jpg
#   inflating: images/images/Turtwig/1.jpg
#   inflating: images/images/Turtwig/2.jpg
#   inflating: images/images/Tympole/0.jpg
#   inflating: images/images/Tympole/1.jpg
#   inflating: images/images/Tynamo/0.jpg
#   inflating: images/images/Tynamo/1.jpg
#   inflating: images/images/Type Null/0.jpg
#   inflating: images/images/Type Null/1.jpg
#   inflating: images/images/Typhlosion/0.jpg
#   inflating: images/images/Typhlosion/1.jpg
#   inflating: images/images/Typhlosion/2.jpg
#   inflating: images/images/Tyranitar/0.jpg
#   inflating: images/images/Tyranitar/1.jpg
#   inflating: images/images/Tyranitar/2.jpg
#   inflating: images/images/Tyranitar/3.jpg
#   inflating: images/images/Tyranitar/4.jpg
#   inflating: images/images/Tyrantrum/0.jpg
#   inflating: images/images/Tyrantrum/1.jpg
#   inflating: images/images/Tyrogue/0.jpg
#   inflating: images/images/Tyrogue/1.jpg
#   inflating: images/images/Tyrogue/2.jpg
#   inflating: images/images/Tyrunt/0.jpg
#   inflating: images/images/Tyrunt/1.jpg
#   inflating: images/images/Umbreon/0.jpg
#   inflating: images/images/Umbreon/1.jpg
#   inflating: images/images/Umbreon/2.jpg
#   inflating: images/images/Unfezant/0.jpg
#   inflating: images/images/Unfezant/1.jpg
#   inflating: images/images/Unfezant/2.jpg
#   inflating: images/images/Unown/0.jpg
#   inflating: images/images/Unown/1.jpg
#   inflating: images/images/Unown/2.jpg
#   inflating: images/images/Unown/3.jpg
#   inflating: images/images/Unown/4.jpg
#   inflating: images/images/Unown/5.jpg
#   inflating: images/images/Ursaring/0.jpg
#   inflating: images/images/Ursaring/1.jpg
#   inflating: images/images/Ursaring/2.jpg
#   inflating: images/images/Urshifu/0.jpg
#   inflating: images/images/Urshifu/1.jpg
#   inflating: images/images/Urshifu/2.jpg
#   inflating: images/images/Urshifu/3.jpg
#   inflating: images/images/Uxie/0.jpg
#   inflating: images/images/Uxie/1.jpg
#   inflating: images/images/Vanillish/0.jpg
#   inflating: images/images/Vanillish/1.jpg
#   inflating: images/images/Vanillite/0.jpg
#   inflating: images/images/Vanillite/1.jpg
#   inflating: images/images/Vanilluxe/0.jpg
#   inflating: images/images/Vanilluxe/1.jpg
#   inflating: images/images/Vaporeon/0.jpg
#   inflating: images/images/Vaporeon/1.jpg
#   inflating: images/images/Vaporeon/2.jpg
#   inflating: images/images/Vaporeon/3.jpg
#   inflating: images/images/Venipede/0.jpg
#   inflating: images/images/Venipede/1.jpg
#   inflating: images/images/Venomoth/0.jpg
#   inflating: images/images/Venomoth/1.jpg
#   inflating: images/images/Venomoth/2.jpg
#   inflating: images/images/Venomoth/3.jpg
#   inflating: images/images/Venonat/0.jpg
#   inflating: images/images/Venonat/1.jpg
#   inflating: images/images/Venonat/2.jpg
#   inflating: images/images/Venonat/3.jpg
#   inflating: images/images/Venusaur/0.jpg
#   inflating: images/images/Venusaur/1.jpg
#   inflating: images/images/Venusaur/2.jpg
#   inflating: images/images/Venusaur/3.jpg
#   inflating: images/images/Venusaur/4.jpg
#   inflating: images/images/Venusaur/5.jpg
#   inflating: images/images/Venusaur/6.jpg
#   inflating: images/images/Venusaur/7.jpg
#   inflating: images/images/Vespiquen/0.jpg
#   inflating: images/images/Vespiquen/1.jpg
#   inflating: images/images/Vibrava/0.jpg
#   inflating: images/images/Vibrava/1.jpg
#   inflating: images/images/Victini/0.jpg
#   inflating: images/images/Victini/1.jpg
#   inflating: images/images/Victreebel/0.jpg
#   inflating: images/images/Victreebel/1.jpg
#   inflating: images/images/Victreebel/2.jpg
#   inflating: images/images/Victreebel/3.jpg
#   inflating: images/images/Vigoroth/0.jpg
#   inflating: images/images/Vigoroth/1.jpg
#   inflating: images/images/Vikavolt/0.jpg
#   inflating: images/images/Vikavolt/1.jpg
#   inflating: images/images/Vileplume/0.jpg
#   inflating: images/images/Vileplume/1.jpg
#   inflating: images/images/Vileplume/2.jpg
#   inflating: images/images/Vileplume/3.jpg
#   inflating: images/images/Virizion/0.jpg
#   inflating: images/images/Virizion/1.jpg
#   inflating: images/images/Vivillon/0.jpg
#   inflating: images/images/Vivillon/1.jpg
#   inflating: images/images/Vivillon/2.jpg
#   inflating: images/images/Vivillon/3.jpg
#   inflating: images/images/Vivillon/4.jpg
#   inflating: images/images/Vivillon/5.jpg
#   inflating: images/images/Volbeat/0.jpg
#   inflating: images/images/Volbeat/1.jpg
#   inflating: images/images/Volcanion/0.jpg
#   inflating: images/images/Volcanion/1.jpg
#   inflating: images/images/Volcarona/0.jpg
#   inflating: images/images/Volcarona/1.jpg
#   inflating: images/images/Voltorb/0.jpg
#   inflating: images/images/Voltorb/1.jpg
#   inflating: images/images/Voltorb/2.jpg
#   inflating: images/images/Voltorb/3.jpg
#   inflating: images/images/Vullaby/0.jpg
#   inflating: images/images/Vullaby/1.jpg
#   inflating: images/images/Vulpix/0.jpg
#   inflating: images/images/Vulpix/1.jpg
#   inflating: images/images/Vulpix/2.jpg
#   inflating: images/images/Wailmer/0.jpg
#   inflating: images/images/Wailmer/1.jpg
#   inflating: images/images/Wailord/0.jpg
#   inflating: images/images/Wailord/1.jpg
#   inflating: images/images/Walrein/0.jpg
#   inflating: images/images/Walrein/1.jpg
#   inflating: images/images/Wartortle/0.jpg
#   inflating: images/images/Wartortle/1.jpg
#   inflating: images/images/Wartortle/2.jpg
#   inflating: images/images/Wartortle/3.jpg
#   inflating: images/images/Watchog/0.jpg
#   inflating: images/images/Watchog/1.jpg
#   inflating: images/images/Weavile/0.jpg
#   inflating: images/images/Weavile/1.jpg
#   inflating: images/images/Weedle/0.jpg
#   inflating: images/images/Weedle/1.jpg
#   inflating: images/images/Weedle/2.jpg
#   inflating: images/images/Weedle/3.jpg
#   inflating: images/images/Weepinbell/0.jpg
#   inflating: images/images/Weepinbell/1.jpg
#   inflating: images/images/Weepinbell/2.jpg
#   inflating: images/images/Weepinbell/3.jpg
#   inflating: images/images/Weezing/0.jpg
#   inflating: images/images/Weezing/1.jpg
#   inflating: images/images/Weezing/2.jpg
#   inflating: images/images/Weezing/3.jpg
#   inflating: images/images/Weezing/4.jpg
#   inflating: images/images/Whimsicott/0.jpg
#   inflating: images/images/Whimsicott/1.jpg
#   inflating: images/images/Whirlipede/0.jpg
#   inflating: images/images/Whirlipede/1.jpg
#   inflating: images/images/Whiscash/0.jpg
#   inflating: images/images/Whiscash/1.jpg
#   inflating: images/images/Whismur/0.jpg
#   inflating: images/images/Whismur/1.jpg
#   inflating: images/images/Wigglytuff/0.jpg
#   inflating: images/images/Wigglytuff/1.jpg
#   inflating: images/images/Wigglytuff/2.jpg
#   inflating: images/images/Wigglytuff/3.jpg
#   inflating: images/images/Wimpod/0.jpg
#   inflating: images/images/Wimpod/1.jpg
#   inflating: images/images/Wingull/0.jpg
#   inflating: images/images/Wingull/1.jpg
#   inflating: images/images/Wishiwashi/0.jpg
#   inflating: images/images/Wishiwashi/1.jpg
#   inflating: images/images/Wishiwashi/2.jpg
#   inflating: images/images/Wishiwashi/3.jpg
#   inflating: images/images/Wobbuffet/0.jpg
#   inflating: images/images/Wobbuffet/1.jpg
#   inflating: images/images/Wobbuffet/2.jpg
#   inflating: images/images/Woobat/0.jpg
#   inflating: images/images/Woobat/1.jpg
#   inflating: images/images/Wooloo/0.jpg
#   inflating: images/images/Wooloo/1.jpg
#   inflating: images/images/Wooper/0.jpg
#   inflating: images/images/Wooper/1.jpg
#   inflating: images/images/Wooper/2.jpg
#   inflating: images/images/Wormadam/0.jpg
#   inflating: images/images/Wormadam/1.jpg
#   inflating: images/images/Wormadam/2.jpg
#   inflating: images/images/Wormadam/3.jpg
#   inflating: images/images/Wormadam/4.jpg
#   inflating: images/images/Wormadam/5.jpg
#   inflating: images/images/Wurmple/0.jpg
#   inflating: images/images/Wurmple/1.jpg
#   inflating: images/images/Wynaut/0.jpg
#   inflating: images/images/Wynaut/1.jpg
#   inflating: images/images/Xatu/0.jpg
#   inflating: images/images/Xatu/1.jpg
#   inflating: images/images/Xatu/2.jpg
#   inflating: images/images/Xerneas/0.jpg
#   inflating: images/images/Xerneas/1.jpg
#   inflating: images/images/Xerneas/2.jpg
#   inflating: images/images/Xerneas/3.jpg
#   inflating: images/images/Xerneas/4.jpg
#   inflating: images/images/Xurkitree/0.jpg
#   inflating: images/images/Xurkitree/1.jpg
#   inflating: images/images/Yamask/0.jpg
#   inflating: images/images/Yamask/1.jpg
#   inflating: images/images/Yamask/2.jpg
#   inflating: images/images/Yamper/0.jpg
#   inflating: images/images/Yamper/1.jpg
#   inflating: images/images/Yanma/0.jpg
#   inflating: images/images/Yanma/1.jpg
#   inflating: images/images/Yanma/2.jpg
#   inflating: images/images/Yanmega/0.jpg
#   inflating: images/images/Yanmega/1.jpg
#   inflating: images/images/Yungoos/0.jpg
#   inflating: images/images/Yungoos/1.jpg
#   inflating: images/images/Yveltal/0.jpg
#   inflating: images/images/Yveltal/1.jpg
#   inflating: images/images/Yveltal/2.jpg
#   inflating: images/images/Yveltal/3.jpg
#   inflating: images/images/Yveltal/4.jpg
#   inflating: images/images/Zacian/0.jpg
#   inflating: images/images/Zacian/1.jpg
#   inflating: images/images/Zacian/2.jpg
#   inflating: images/images/Zamazenta/0.jpg
#   inflating: images/images/Zamazenta/1.jpg
#   inflating: images/images/Zamazenta/2.jpg
#   inflating: images/images/Zangoose/0.jpg
#   inflating: images/images/Zangoose/1.jpg
#   inflating: images/images/Zapdos/0.jpg
#   inflating: images/images/Zapdos/1.jpg
#   inflating: images/images/Zapdos/2.jpg
#   inflating: images/images/Zapdos/3.jpg
#   inflating: images/images/Zapdos/4.jpg
#   inflating: images/images/Zapdos/5.jpg
#   inflating: images/images/Zarude/0.jpg
#   inflating: images/images/Zarude/1.jpg
#   inflating: images/images/Zebstrika/0.jpg
#   inflating: images/images/Zebstrika/1.jpg
#   inflating: images/images/Zekrom/0.jpg
#   inflating: images/images/Zekrom/1.jpg
#   inflating: images/images/Zekrom/2.jpg
#   inflating: images/images/Zekrom/3.jpg
#   inflating: images/images/Zeraora/0.jpg
#   inflating: images/images/Zeraora/1.jpg
#   inflating: images/images/Zeraora/2.jpg
#   inflating: images/images/Zigzagoon/0.jpg
#   inflating: images/images/Zigzagoon/1.jpg
#   inflating: images/images/Zigzagoon/2.jpg
#   inflating: images/images/Zoroark/0.jpg
#   inflating: images/images/Zoroark/1.jpg
#   inflating: images/images/Zorua/0.jpg
#   inflating: images/images/Zorua/1.jpg
#   inflating: images/images/Zubat/0.jpg
#   inflating: images/images/Zubat/1.jpg
#   inflating: images/images/Zubat/2.jpg
#   inflating: images/images/Zubat/3.jpg
#   inflating: images/images/Zweilous/0.jpg
#   inflating: images/images/Zweilous/1.jpg
#   inflating: images/images/Zygarde/0.jpg
#   inflating: images/images/Zygarde/1.jpg
#   inflating: images/images/Zygarde/2.jpg
#   inflating: images/images/Zygarde/3.jpg
#   inflating: images/images/Zygarde/4.jpg
#   inflating: images/images/Zygarde/5.jpg

# %%
# We can use an image folder dataset the way we have it setup.
# Create the dataset
dataset = dset.ImageFolder(root=dataroot,
                           transform=transforms.Compose([
                               transforms.Resize(image_size),
                               transforms.CenterCrop(image_size),
                               transforms.ToTensor(),
                               transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                           ]))
# Create the dataloader
dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                                         shuffle=True, num_workers=workers)

# Decide which device we want to run on
device = torch.device("cuda:0" if (torch.cuda.is_available() and ngpu > 0) else "cpu")

# Plot some training images
real_batch = next(iter(dataloader))
plt.figure(figsize=(8,8))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch[0].to(device)[:64], padding=2, normalize=True).cpu(),(1,2,0)))
plt.show()

# %% [markdown]
# Implementation
# ==============
#
# With our input parameters set and the dataset prepared, we can now get
# into the implementation. We will start with the weight initialization
# strategy, then talk about the generator, discriminator, loss functions,
# and training loop in detail.
#
# Weight Initialization
# ---------------------
#
# From the DCGAN paper, the authors specify that all model weights shall
# be randomly initialized from a Normal distribution with `mean=0`,
# `stdev=0.02`. The `weights_init` function takes an initialized model as
# input and reinitializes all convolutional, convolutional-transpose, and
# batch normalization layers to meet this criteria. This function is
# applied to the models immediately after initialization.

# %%
# custom weights initialization called on ``netG`` and ``netD``
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

# %% [markdown]
# Generator
# =========
#
# The generator, $G$, is designed to map the latent space vector ($z$) to
# data-space. Since our data are images, converting $z$ to data-space
# means ultimately creating a RGB image with the same size as the training
# images (i.e. 3x64x64). In practice, this is accomplished through a
# series of strided two dimensional convolutional transpose layers, each
# paired with a 2d batch norm layer and a relu activation. The output of
# the generator is fed through a tanh function to return it to the input
# data range of $[-1,1]$. It is worth noting the existence of the batch
# norm functions after the conv-transpose layers, as this is a critical
# contribution of the DCGAN paper. These layers help with the flow of
# gradients during training. An image of the generator from the DCGAN
# paper is shown below.
#
# ![](https://pytorch.org/tutorials/_static/img/dcgan_generator.png)
#
# Notice, how the inputs we set in the input section (`nz`, `ngf`, and
# `nc`) influence the generator architecture in code. `nz` is the length
# of the z input vector, `ngf` relates to the size of the feature maps
# that are propagated through the generator, and `nc` is the number of
# channels in the output image (set to 3 for RGB images). Below is the
# code for the generator.

# %%
# Generator Code

class Generator(nn.Module):
    def __init__(self, ngpu):
        super(Generator, self).__init__()
        self.ngpu = ngpu
        self.main = nn.Sequential(
            # input is Z, going into a convolution
            nn.ConvTranspose2d( nz, ngf * 8, 4, 1, 0, bias=False),
            nn.BatchNorm2d(ngf * 8),
            nn.ReLU(True),
            # state size. ``(ngf*8) x 4 x 4``
            nn.ConvTranspose2d(ngf * 8, ngf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 4),
            nn.ReLU(True),
            # state size. ``(ngf*4) x 8 x 8``
            nn.ConvTranspose2d( ngf * 4, ngf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 2),
            nn.ReLU(True),
            # state size. ``(ngf*2) x 16 x 16``
            nn.ConvTranspose2d( ngf * 2, ngf, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf),
            nn.ReLU(True),
            # state size. ``(ngf) x 32 x 32``
            nn.ConvTranspose2d( ngf, nc, 4, 2, 1, bias=False),
            nn.Tanh()
            # state size. ``(nc) x 64 x 64``
        )

    def forward(self, input):
        return self.main(input)

# %% [markdown]
# Now, we can instantiate the generator and apply the `weights_init`
# function. Check out the printed model to see how the generator object is
# structured.

# %%
# Create the generator
netG = Generator(ngpu).to(device)

# Handle multi-GPU if desired
if (device.type == 'cuda') and (ngpu > 1):
    netG = nn.DataParallel(netG, list(range(ngpu)))

# Apply the ``weights_init`` function to randomly initialize all weights
#  to ``mean=0``, ``stdev=0.02``.
netG.apply(weights_init)

# Print the model
print(netG)
# Out:
# Generator(
#   (main): Sequential(
#     (0): ConvTranspose2d(100, 512, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU(inplace=True)
#     (9): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): ReLU(inplace=True)
#     (12): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (13): Tanh()
#   )
# )

# %% [markdown]
# Discriminator
# =============
#
# As mentioned, the discriminator, $D$, is a binary classification network
# that takes an image as input and outputs a scalar probability that the
# input image is real (as opposed to fake). Here, $D$ takes a 3x64x64
# input image, processes it through a series of Conv2d, BatchNorm2d, and
# LeakyReLU layers, and outputs the final probability through a Sigmoid
# activation function. This architecture can be extended with more layers
# if necessary for the problem, but there is significance to the use of
# the strided convolution, BatchNorm, and LeakyReLUs. The DCGAN paper
# mentions it is a good practice to use strided convolution rather than
# pooling to downsample because it lets the network learn its own pooling
# function. Also batch norm and leaky relu functions promote healthy
# gradient flow which is critical for the learning process of both $G$ and
# $D$.

# %% [markdown]
# Discriminator Code

# %%
class Discriminator(nn.Module):
    def __init__(self, ngpu):
        super(Discriminator, self).__init__()
        self.ngpu = ngpu
        self.main = nn.Sequential(
            # input is ``(nc) x 64 x 64``
            nn.Conv2d(nc, ndf, 4, 2, 1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),
            # state size. ``(ndf) x 32 x 32``
            nn.Conv2d(ndf, ndf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 2),
            nn.LeakyReLU(0.2, inplace=True),
            # state size. ``(ndf*2) x 16 x 16``
            nn.Conv2d(ndf * 2, ndf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 4),
            nn.LeakyReLU(0.2, inplace=True),
            # state size. ``(ndf*4) x 8 x 8``
            nn.Conv2d(ndf * 4, ndf * 8, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 8),
            nn.LeakyReLU(0.2, inplace=True),
            # state size. ``(ndf*8) x 4 x 4``
            nn.Conv2d(ndf * 8, 1, 4, 1, 0, bias=False),
            nn.Sigmoid()
        )

    def forward(self, input):
        return self.main(input)

# %% [markdown]
# Now, as with the generator, we can create the discriminator, apply the
# `weights_init` function, and print the model's structure.

# %%
# Create the Discriminator
netD = Discriminator(ngpu).to(device)

# Handle multi-GPU if desired
if (device.type == 'cuda') and (ngpu > 1):
    netD = nn.DataParallel(netD, list(range(ngpu)))

# Apply the ``weights_init`` function to randomly initialize all weights
# like this: ``to mean=0, stdev=0.2``.
netD.apply(weights_init)

# Print the model
print(netD)
# Out:
# Discriminator(
#   (main): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (9): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2, inplace=True)
#     (11): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (12): Sigmoid()
#   )
# )

# %% [markdown]
# Loss Functions and Optimizers
# =============================
#
# With $D$ and $G$ setup, we can specify how they learn through the loss
# functions and optimizers. We will use the Binary Cross Entropy loss
# ([BCELoss](https://pytorch.org/docs/stable/generated/torch.nn.BCELoss.html#torch.nn.BCELoss))
# function which is defined in PyTorch as:
#
# $$\ell(x, y) = L = \{l_1,\dots,l_N\}^\top, \quad l_n = - \left[ y_n \cdot \log x_n + (1 - y_n) \cdot \log (1 - x_n) \right]$$
#
# Notice how this function provides the calculation of both log components
# in the objective function (i.e. $log(D(x))$ and $log(1-D(G(z)))$). We
# can specify what part of the BCE equation to use with the $y$ input.
# This is accomplished in the training loop which is coming up soon, but
# it is important to understand how we can choose which component we wish
# to calculate just by changing $y$ (i.e. GT labels).
#
# Next, we define our real label as 1 and the fake label as 0. These
# labels will be used when calculating the losses of $D$ and $G$, and this
# is also the convention used in the original GAN paper. Finally, we set
# up two separate optimizers, one for $D$ and one for $G$. As specified in
# the DCGAN paper, both are Adam optimizers with learning rate 0.0002 and
# Beta1 = 0.5. For keeping track of the generator's learning progression,
# we will generate a fixed batch of latent vectors that are drawn from a
# Gaussian distribution (i.e. fixed\_noise) . In the training loop, we
# will periodically input this fixed\_noise into $G$, and over the
# iterations we will see images form out of the noise.

# %%
# Initialize the ``BCELoss`` function
criterion = nn.BCELoss()

# Create batch of latent vectors that we will use to visualize
#  the progression of the generator
fixed_noise = torch.randn(64, nz, 1, 1, device=device)

# Establish convention for real and fake labels during training
real_label = 1.
fake_label = 0.

# Setup Adam optimizers for both G and D
optimizerD = optim.Adam(netD.parameters(), lr=lr, betas=(beta1, 0.999))
optimizerG = optim.Adam(netG.parameters(), lr=lr, betas=(beta1, 0.999))

# %% [markdown]
# Training
# ========
#
# Finally, now that we have all of the parts of the GAN framework defined,
# we can train it. Be mindful that training GANs is somewhat of an art
# form, as incorrect hyperparameter settings lead to mode collapse with
# little explanation of what went wrong. Here, we will closely follow
# Algorithm 1 from the [Goodfellow's
# paper](https://papers.nips.cc/paper/5423-generative-adversarial-nets.pdf),
# while abiding by some of the best practices shown in
# [ganhacks](https://github.com/soumith/ganhacks). Namely, we will
# "construct different mini-batches for real and fake" images, and also
# adjust G's objective function to maximize $log(D(G(z)))$. Training is
# split up into two main parts. Part 1 updates the Discriminator and Part
# 2 updates the Generator.
#
# **Part 1 - Train the Discriminator**
#
# Recall, the goal of training the discriminator is to maximize the
# probability of correctly classifying a given input as real or fake. In
# terms of Goodfellow, we wish to "update the discriminator by ascending
# its stochastic gradient". Practically, we want to maximize
# $log(D(x)) + log(1-D(G(z)))$. Due to the separate mini-batch suggestion
# from [ganhacks](https://github.com/soumith/ganhacks), we will calculate
# this in two steps. First, we will construct a batch of real samples from
# the training set, forward pass through $D$, calculate the loss
# ($log(D(x))$), then calculate the gradients in a backward pass.
# Secondly, we will construct a batch of fake samples with the current
# generator, forward pass this batch through $D$, calculate the loss
# ($log(1-D(G(z)))$), and *accumulate* the gradients with a backward pass.
# Now, with the gradients accumulated from both the all-real and all-fake
# batches, we call a step of the Discriminator's optimizer.
#
# **Part 2 - Train the Generator**
#
# As stated in the original paper, we want to train the Generator by
# minimizing $log(1-D(G(z)))$ in an effort to generate better fakes. As
# mentioned, this was shown by Goodfellow to not provide sufficient
# gradients, especially early in the learning process. As a fix, we
# instead wish to maximize $log(D(G(z)))$. In the code we accomplish this
# by: classifying the Generator output from Part 1 with the Discriminator,
# computing G's loss *using real labels as GT*, computing G's gradients in
# a backward pass, and finally updating G's parameters with an optimizer
# step. It may seem counter-intuitive to use the real labels as GT labels
# for the loss function, but this allows us to use the $log(x)$ part of
# the `BCELoss` (rather than the $log(1-x)$ part) which is exactly what we
# want.
#
# Finally, we will do some statistic reporting and at the end of each
# epoch we will push our fixed\_noise batch through the generator to
# visually track the progress of G's training. The training statistics
# reported are:
#
# -   **Loss\_D** - discriminator loss calculated as the sum of losses for
#     the all real and all fake batches ($log(D(x)) + log(1 - D(G(z)))$).
# -   **Loss\_G** - generator loss calculated as $log(D(G(z)))$
# -   **D(x)** - the average output (across the batch) of the
#     discriminator for the all real batch. This should start close to 1
#     then theoretically converge to 0.5 when G gets better. Think about
#     why this is.
# -   **D(G(z))** - average discriminator outputs for the all fake batch.
#     The first number is before D is updated and the second number is
#     after D is updated. These numbers should start near 0 and converge
#     to 0.5 as G gets better. Think about why this is.
#
# **Note:** This step might take a while, depending on how many epochs you
# run and if you removed some data from the dataset.

# %%
# Training Loop

# Lists to keep track of progress
img_list = []
G_losses = []
D_losses = []
iters = 0

print("Starting Training Loop...")
# For each epoch
for epoch in range(num_epochs):
    # For each batch in the dataloader
    for i, data in enumerate(dataloader, 0):

        ############################
        # (1) Update D network: maximize log(D(x)) + log(1 - D(G(z)))
        ###########################
        ## Train with all-real batch
        netD.zero_grad()
        # Format batch
        real_cpu = data[0].to(device)
        b_size = real_cpu.size(0)
        label = torch.full((b_size,), real_label, dtype=torch.float, device=device)
        # Forward pass real batch through D
        output = netD(real_cpu).view(-1)
        # Calculate loss on all-real batch
        errD_real = criterion(output, label)
        # Calculate gradients for D in backward pass
        errD_real.backward()
        D_x = output.mean().item()

        ## Train with all-fake batch
        # Generate batch of latent vectors
        noise = torch.randn(b_size, nz, 1, 1, device=device)
        # Generate fake image batch with G
        fake = netG(noise)
        label.fill_(fake_label)
        # Classify all fake batch with D
        output = netD(fake.detach()).view(-1)
        # Calculate D's loss on the all-fake batch
        errD_fake = criterion(output, label)
        # Calculate the gradients for this batch, accumulated (summed) with previous gradients
        errD_fake.backward()
        D_G_z1 = output.mean().item()
        # Compute error of D as sum over the fake and the real batches
        errD = errD_real + errD_fake
        # Update D
        optimizerD.step()

        ############################
        # (2) Update G network: maximize log(D(G(z)))
        ###########################
        netG.zero_grad()
        label.fill_(real_label)  # fake labels are real for generator cost
        # Since we just updated D, perform another forward pass of all-fake batch through D
        output = netD(fake).view(-1)
        # Calculate G's loss based on this output
        errG = criterion(output, label)
        # Calculate gradients for G
        errG.backward()
        D_G_z2 = output.mean().item()
        # Update G
        optimizerG.step()

        # Output training stats
        if i % 50 == 0:
            print('[%d/%d][%d/%d]\tLoss_D: %.4f\tLoss_G: %.4f\tD(x): %.4f\tD(G(z)): %.4f / %.4f'
                  % (epoch, num_epochs, i, len(dataloader),
                     errD.item(), errG.item(), D_x, D_G_z1, D_G_z2))

        # Save Losses for plotting later
        G_losses.append(errG.item())
        D_losses.append(errD.item())

        # Check how the generator is doing by saving G's output on fixed_noise
        if (iters % 500 == 0) or ((epoch == num_epochs-1) and (i == len(dataloader)-1)):
            with torch.no_grad():
                fake = netG(fixed_noise).detach().cpu()
            img_list.append(vutils.make_grid(fake, padding=2, normalize=True))

        iters += 1
# Out:
# Starting Training Loop...
# [0/20][0/157]	Loss_D: 1.6577	Loss_G: 7.8627	D(x): 0.6015	D(G(z)): 0.6098 / 0.0006
# [0/20][50/157]	Loss_D: 1.7863	Loss_G: 14.3581	D(x): 0.2744	D(G(z)): 0.0000 / 0.0000
# [0/20][100/157]	Loss_D: 1.7154	Loss_G: 4.0449	D(x): 0.6402	D(G(z)): 0.4224 / 0.0444
# [0/20][150/157]	Loss_D: 0.2037	Loss_G: 4.4155	D(x): 0.9690	D(G(z)): 0.1470 / 0.0169
# [1/20][0/157]	Loss_D: 0.2407	Loss_G: 4.1250	D(x): 0.8451	D(G(z)): 0.0508 / 0.0205
# [1/20][50/157]	Loss_D: 0.1909	Loss_G: 4.7120	D(x): 0.8728	D(G(z)): 0.0418 / 0.0124
# [1/20][100/157]	Loss_D: 0.1364	Loss_G: 5.3200	D(x): 0.9297	D(G(z)): 0.0532 / 0.0099
# [1/20][150/157]	Loss_D: 0.0516	Loss_G: 5.1026	D(x): 0.9781	D(G(z)): 0.0278 / 0.0116
# [2/20][0/157]	Loss_D: 3.8193	Loss_G: 9.1344	D(x): 0.9990	D(G(z)): 0.9579 / 0.0004
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 43
#      41 errD_fake = criterion(output, label)
#      42 # Calculate the gradients for this batch, accumulated (summed) with previous gradients
# ---> 43 errD_fake.backward()
#      44 D_G_z1 = output.mean().item()
#      45 # Compute error of D as sum over the fake and the real batches
#
# File ~/.local/lib/python3.13/site-packages/torch/_tensor.py:626, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     616 if has_torch_function_unary(self):
#     617     return handle_torch_function(
#     618         Tensor.backward,
#     619         (self,),
#    (...)
#     624         inputs=inputs,
#     625     )
# --> 626 torch.autograd.backward(
#     627     self, gradient, retain_graph, create_graph, inputs=inputs
#     628 )
#
# File ~/.local/lib/python3.13/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File ~/.local/lib/python3.13/site-packages/torch/autograd/graph.py:823, in _engine_run_backward(t_outputs, *args, **kwargs)
#     821     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822 try:
# --> 823     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824         t_outputs, *args, **kwargs
#     825     )  # Calls into the C++ engine to run the backward pass
#     826 finally:
#     827     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# Results
# =======
#
# Finally, lets check out how we did. Here, we will look at three
# different results. First, we will see how D and G's losses changed
# during training. Second, we will visualize G's output on the
# fixed\_noise batch for every epoch. And third, we will look at a batch
# of real data next to a batch of fake data from G.
#
# **Loss versus training iteration**
#
# Below is a plot of D & G's losses versus training iterations.

# %%
plt.figure(figsize=(10,5))
plt.title("Generator and Discriminator Loss During Training")
plt.plot(G_losses,label="G")
plt.plot(D_losses,label="D")
plt.xlabel("iterations")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# **Visualization of G's progression**
#
# Remember how we saved the generator's output on the fixed\_noise batch
# after every epoch of training. Now, we can visualize the training
# progression of G with an animation. Press the play button to start the
# animation.

# %%
fig = plt.figure(figsize=(8,8))
plt.axis("off")
ims = [[plt.imshow(np.transpose(i,(1,2,0)), animated=True)] for i in img_list]
ani = animation.ArtistAnimation(fig, ims, interval=1000, repeat_delay=1000, blit=True)

HTML(ani.to_jshtml())

# %% [markdown]
# **Real Images vs. Fake Images**
#
# Finally, lets take a look at some real images and fake images side by
# side.

# %%
# Grab a batch of real images from the dataloader
real_batch = next(iter(dataloader))

# Plot the real images
plt.figure(figsize=(15,15))
plt.subplot(1,2,1)
plt.axis("off")
plt.title("Real Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch[0].to(device)[:64], padding=5, normalize=True).cpu(),(1,2,0)))

# Plot the fake images from the last epoch
plt.subplot(1,2,2)
plt.axis("off")
plt.title("Fake Images")
plt.imshow(np.transpose(img_list[-1],(1,2,0)))
plt.show()

# %% [markdown]
# Where to Go Next
# ================
#
# We have reached the end of our journey, but there are several places you
# could go from here. You could:
#
# -   Train for longer to see how good the results get
# -   Modify this model to take a different dataset and possibly change
#     the size of the images and the model architecture
# -   Check out some other cool GAN projects
#     [here](https://github.com/nashory/gans-awesome-applications)
# -   Create GANs that generate
#     [music](https://www.deepmind.com/blog/wavenet-a-generative-model-for-raw-audio/)
